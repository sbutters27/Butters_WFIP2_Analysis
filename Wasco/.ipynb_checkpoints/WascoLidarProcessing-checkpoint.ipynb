# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import glob
import xarray as xr
from numpy.lib.stride_tricks import as_strided as strided

# %%
# ESRL Lidar, Not used

# Was1=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20150901.000000.windprof.nc.a2e.nc')
# Was1df=Was1.to_dataframe()

# Was2=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20151001.000000.windprof.nc.a2e.nc')
# Was2df=Was2.to_dataframe()

# Was3=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20151101.000000.windprof.nc.a2e.nc')
# Was3df=Was3.to_dataframe()

# Was4=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20151201.000000.windprof.nc.a2e.nc')
# Was4df=Was4.to_dataframe()

# Was5=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160101.000000.windprof.nc.a2e.nc')
# Was5df=Was5.to_dataframe()

# Was6=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160201.000000.windprof.nc.a2e.nc')
# Was6df=Was6.to_dataframe()

# Was7=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160301.000000.windprof.nc.a2e.nc')
# Was7df=Was7.to_dataframe()

# Was8=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160401.000000.windprof.nc.a2e.nc')
# Was8df=Was8.to_dataframe()

# Was9=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160501.000000.windprof.nc.a2e.nc')
# Was9df=Was9.to_dataframe()

# Was10=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160601.000000.windprof.nc.a2e.nc')
# Was10df=Was10.to_dataframe()

# Was11=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160701.000000.windprof.nc.a2e.nc')
# Was11df=Was11.to_dataframe()

# Was12=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160801.000000.windprof.nc.a2e.nc')
# Was12df=Was12.to_dataframe()

# Was13=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20160901.000000.windprof.nc.a2e.nc')
# Was13df=Was13.to_dataframe()

# Was14=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20161001.000000.windprof.nc.a2e.nc')
# Was14df=Was14.to_dataframe()

# Was15=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20161101.000000.windprof.nc.a2e.nc')
# Was15df=Was15.to_dataframe()

# Was16=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20161201.000000.windprof.nc.a2e.nc')
# Was16df=Was16.to_dataframe()

# Was17=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20170101.000000.windprof.nc.a2e.nc')
# Was17df=Was17.to_dataframe()

# Was18=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20170201.000000.windprof.nc.a2e.nc')
# Was18df=Was18.to_dataframe()

# Was19=xr.open_mfdataset('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/lidar.z04.b0.20170301.000000.windprof.nc.a2e.nc')
# Was19df=Was19.to_dataframe()

# WasWSdf=pd.concat([Was1df,Was2df,Was3df,Was4df,Was5df,Was6df,Was7df,Was8df,Was9df,Was10df,Was11df,Was12df,Was13df,Was14df,Was15df,Was16df,Was17df,Was18df,Was19df])

# WasWSdf.reset_index(inplace=True)

# del WasWSdf['time_bounds']
# del WasWSdf['wind_speed_std']
# del WasWSdf['wind_direction']
# del WasWSdf['wind_direction_std']
# del WasWSdf['latitude']
# del WasWSdf['longitude']
# del WasWSdf['altitude']
# del WasWSdf['bounds']

# WasWSdf=WasWSdf[(WasWSdf.height<300)]

# WasWSdf['height']=[round(ht) for ht in WasWSdf.height]

# sorted(WasWSdf.height.unique())

# %%
path = '/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/CU'
all_files = sorted(glob.glob(path + "/*.sta"))

li = []

for filename in all_files:
#     print(filename)
    df = pd.read_csv(filename,sep='\t',header=56, encoding='iso-8859-1')
    li.append(df)

WasWSdf = pd.concat(li, axis=0, ignore_index=True)
WasWSdf.set_index('Date',inplace=True)

# %%
# del WasWSdf['WiperCount']
# del WasWSdf['Tm']
# del WasWSdf['dVh1']
# del WasWSdf['VhMax1']
# del WasWSdf['VhMin1']
# del WasWSdf['Azim1']
# del WasWSdf['um1']
# del WasWSdf['du1']
# del WasWSdf['vm1']
# del WasWSdf['dv1']
# del WasWSdf['wm1']
# del WasWSdf['dw1']
# del WasWSdf['CNRm']
# del WasWSdf['dCNR']
# del WasWSdf['CNRmax']
# del WasWSdf['CNRmin']
# del WasWSdf['spectral']

WasWSdf.columns
# Out:
# Index(['WiperCount', 'Tm', 'Vhm1', 'dVh1', 'VhMax1', 'VhMin1', 'Azim1', 'um1',
#        'du1', 'vm1',
#        ...
#        'wm10', 'dw10', 'CNRm.9', 'dCNR.9', 'CNRmax.9', 'CNRmin.9',
#        'spectral_broadening.9', 'dspectral_broadening.9', 'Avail.10',
#        'Unnamed: 192'],
#       dtype='object', length=192)

# %%
for col in WasWSdf.columns:
    if 'Vhm' in col:
        print(col)
    else: 
        del WasWSdf[col]
# Out:
# Vhm1
# Vhm2
# Vhm3
# Vhm4
# Vhm5
# Vhm6
# Vhm7
# Vhm8
# Vhm9
# Vhm10

# %%
WasWSdf = WasWSdf.rename({'Vhm1': '40m', 'Vhm2': '60m','Vhm3': '80m','Vhm4': '100m','Vhm5': '120m','Vhm6': '140m','Vhm7': '160m','Vhm8': '180m','Vhm9': '200m','Vhm10': '220m'}, axis=1)

# %%
WasWSdf.to_csv('WascoLidar2min')

# %%
def mask_knans(a, x):
    a = np.asarray(a)
    k = a.size
    n = np.append(np.isnan(a), [False] * (x - 1))
    m = np.empty(k, np.bool8)
    m.fill(True)

    s = n.strides[0]
    i = np.where(strided(n, (k + 1 - x, x), (s, s)).all(1))[0][:, None]
    i = i + np.arange(x)
    i = pd.unique(i[i < k])

    m[i] = False

    return m

# %%
WasWSdfIntp=WasWSdf

print('height,points,#NaN,%Nan,#RescuablePoints')
for height in WasWSdf.columns:
    tot=len(WasWSdf[height])
    drop=len(WasWSdf[height].dropna())
    x=WasWSdf[height].interpolate().where(mask_knans(WasWSdf[height].tolist(),15))
    y=x.dropna()                                                                  
    print(height,tot,tot-drop,round(100*(tot-drop)/tot),100*len(x.dropna())-drop, (len(x.dropna())-drop)/tot)
# Out:
# height,points,#NaN,%Nan,#RescuablePoints
# 40m 214948 11813 5 20620865 0.02374993021568007
# 60m 214948 8678 4 20826930 0.018897593836648865
# 80m 214948 13658 6 20192910 0.012337867763366024
# 100m 214948 13378 6 20199230 0.011342278132385508
# 120m 214948 15471 7 20066723 0.014817537264826841
# 140m 214948 21730 10 19674582 0.025401492453988872
# 160m 214948 35244 16 18846596 0.04912350894169753
# 180m 214948 60618 28 16908170 0.07580903288237155
# 200m 214948 92466 43 14196418 0.09633492751735304
# 220m 214948 122765 57 11085617 0.09116158326665054

# %%
WasWSdfIntp['40m']=WasWSdf['40m'].interpolate().where(mask_knans(WasWSdf['40m'].tolist(),15))
WasWSdfIntp['60m']=WasWSdf['60m'].interpolate().where(mask_knans(WasWSdf['60m'].tolist(),15))
WasWSdfIntp['80m']=WasWSdf['80m'].interpolate().where(mask_knans(WasWSdf['80m'].tolist(),15))
WasWSdfIntp['100m']=WasWSdf['100m'].interpolate().where(mask_knans(WasWSdf['100m'].tolist(),15))
WasWSdfIntp['120m']=WasWSdf['120m'].interpolate().where(mask_knans(WasWSdf['120m'].tolist(),15))
WasWSdfIntp['140m']=WasWSdf['140m'].interpolate().where(mask_knans(WasWSdf['140m'].tolist(),15))
WasWSdfIntp['160m']=WasWSdf['160m'].interpolate().where(mask_knans(WasWSdf['160m'].tolist(),15))
WasWSdfIntp['180m']=WasWSdf['180m'].interpolate().where(mask_knans(WasWSdf['180m'].tolist(),15))
WasWSdfIntp['200m']=WasWSdf['200m'].interpolate().where(mask_knans(WasWSdf['200m'].tolist(),15))

WasWSdfIntp.to_csv('WascoLidarInterpolated2min')

# %%
WasWSdfIntpHr=WasWSdf
WasWSdfIntpHr.index=pd.to_datetime(WasWSdfIntpHr.index)
WasWSdfIntpHr

WasWS40IntpHr=WasWSdfIntpHr['40m'].resample('1H').mean()
WasWS60IntpHr=WasWSdfIntpHr['60m'].resample('1H').mean()
WasWS80IntpHr=WasWSdfIntpHr['80m'].resample('1H').mean()
WasWS100IntpHr=WasWSdfIntpHr['100m'].resample('1H').mean()
WasWS120IntpHr=WasWSdfIntpHr['120m'].resample('1H').mean()
WasWS140IntpHr=WasWSdfIntpHr['140m'].resample('1H').mean()
WasWS160IntpHr=WasWSdfIntpHr['160m'].resample('1H').mean()
WasWS180IntpHr=WasWSdfIntpHr['180m'].resample('1H').mean()
WasWS200IntpHr=WasWSdfIntpHr['200m'].resample('1H').mean()

WasWSdfIntpHr=pd.concat((WasWS40IntpHr,WasWS60IntpHr,WasWS80IntpHr,WasWS100IntpHr,WasWS120IntpHr,WasWS140IntpHr,WasWS160IntpHr,WasWS180IntpHr,WasWS200IntpHr),axis=1)
WasWSdfIntpHr.to_csv('WascoLidarInterpolatedHourly')

# %%
WasWSdfIntpHr
# Out:
#                           40m       60m       80m      100m      120m  \
# Date
# 2016-01-03 00:00:00  3.365333  3.459333  3.467667  3.429667  3.344333
# 2016-01-03 01:00:00  3.101667  3.379667  3.468000  3.425667  3.326000
# 2016-01-03 02:00:00  3.093667  3.538667  3.390667  3.150667  3.059333
# 2016-01-03 03:00:00  3.121667  3.595667  3.439667  3.104667  2.737000
# 2016-01-03 04:00:00  1.938000  2.207000  2.171333  2.094333  2.006333
# ...                       ...       ...       ...       ...       ...
# 2017-12-01 19:00:00  3.352667  3.388667  3.443000  3.570000  3.578333
# 2017-12-01 20:00:00  3.678333  3.622667  3.452333  3.374000  3.379667
# 2017-12-01 21:00:00  2.979667  3.071667  3.245333  3.457333  3.647333
# 2017-12-01 22:00:00  3.224000  3.312000  3.369667  3.484333  3.618000
# 2017-12-01 23:00:00  2.195333  2.216000  2.324333  2.259333  2.228000
#
#                          140m      160m      180m      200m
# Date
# ...

# %%
NaN=[4,6,6,7,10]
After=[2,1,1,1,3]
index=[60,80,100,120,140]
NanFrame=pd.DataFrame({'NaN Post-Processing':After,'NaN Pre-Processing':NaN},index=index)
ax=NanFrame.plot.barh()
plt.ylabel('Height (m)')
plt.xlabel('Percetage of data (%)')
plt.title('WAS')
plt.savefig('WASNan')
plt.show()
