# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import wasserstein_distance
import glob
import os
import xarray as xr
from matplotlib.pyplot import figure
import skill_metrics as sm
plt.close('all')

# %% [markdown]
# Reading in data: for each dataset (ERA-5, WRF, MERRA-2, Lidar), I follow the same steps:
# 1. read in the file to a dataframe
# 2. create an array of zeros and fill it with values for each height
# 3. create an array of zeros for each season and fill it with values for each height
# 4. create dataframes that show the mean and standard deviation for diurnal cycle overall and during each season

# %%
# Wasco ERA5

# read in file
WascoERAdf=pd.read_csv('/projects/sebu3651/ProjectResearch/Wasco/WascoERA5/WascoERA')
WascoERAdf.set_index('time', inplace=True)

# filter dataframe to match observational period
WascoERAdf=WascoERAdf[(WascoERAdf.index >='2016-02-01 00:00:00')&(WascoERAdf.index<='2017-01-31 23:00:00') ]

# create array of zeros and fill with wind speed data for each height
WascoERAWS=np.zeros((8784,11))
WascoERAWS[:,10]=WascoERAdf[WascoERAdf.height==10]['wind speed']
WascoERAWS[:,9]=WascoERAdf[WascoERAdf.height==31]['wind speed']
WascoERAWS[:,8]=WascoERAdf[WascoERAdf.height==54]['wind speed']
WascoERAWS[:,7]=WascoERAdf[WascoERAdf.height==79]['wind speed']
WascoERAWS[:,6]=WascoERAdf[WascoERAdf.height==106]['wind speed']
WascoERAWS[:,5]=WascoERAdf[WascoERAdf.height==137]['wind speed']
WascoERAWS[:,4]=WascoERAdf[WascoERAdf.height==170]['wind speed']
WascoERAWS[:,3]=WascoERAdf[WascoERAdf.height==205]['wind speed']
WascoERAWS[:,2]=WascoERAdf[WascoERAdf.height==245]['wind speed']
WascoERAWS[:,1]=WascoERAdf[WascoERAdf.height==288]['wind speed']
WascoERAWS[:,0]=WascoERAdf[WascoERAdf.height==334]['wind speed']

# list of z values for ERA-5 heights
WascoERAZ=[334, 288, 245, 205, 170, 137, 106, 79, 54, 31, 10]

# %%
# creating winter ERA5 array
WascoERADJFdf=WascoERAdf[(WascoERAdf.index.str.contains('-12-'))|(WascoERAdf.index.str.contains('-01-'))|(WascoERAdf.index.str.contains('-02-'))]
WascoERAWSDJF=np.zeros((2184,11))
WascoERAWSDJF[:,10]=WascoERADJFdf[WascoERADJFdf.height==10]['wind speed']
WascoERAWSDJF[:,9]=WascoERADJFdf[WascoERADJFdf.height==31]['wind speed']
WascoERAWSDJF[:,8]=WascoERADJFdf[WascoERADJFdf.height==54]['wind speed']
WascoERAWSDJF[:,7]=WascoERADJFdf[WascoERADJFdf.height==79]['wind speed']
WascoERAWSDJF[:,6]=WascoERADJFdf[WascoERADJFdf.height==106]['wind speed']
WascoERAWSDJF[:,5]=WascoERADJFdf[WascoERADJFdf.height==137]['wind speed']
WascoERAWSDJF[:,4]=WascoERADJFdf[WascoERADJFdf.height==170]['wind speed']
WascoERAWSDJF[:,3]=WascoERADJFdf[WascoERADJFdf.height==205]['wind speed']
WascoERAWSDJF[:,2]=WascoERADJFdf[WascoERADJFdf.height==245]['wind speed']
WascoERAWSDJF[:,1]=WascoERADJFdf[WascoERADJFdf.height==288]['wind speed']
WascoERAWSDJF[:,0]=WascoERADJFdf[WascoERADJFdf.height==334]['wind speed']

# creating spring eRA5 array
WascoERAMAMdf=WascoERAdf[(WascoERAdf.index.str.contains('-03-'))|(WascoERAdf.index.str.contains('-04-'))|(WascoERAdf.index.str.contains('-05-'))]
WascoERAWSMAM=np.zeros((2208,11))
WascoERAWSMAM[:,10]=WascoERAMAMdf[WascoERAMAMdf.height==10]['wind speed']
WascoERAWSMAM[:,9]=WascoERAMAMdf[WascoERAMAMdf.height==31]['wind speed']
WascoERAWSMAM[:,8]=WascoERAMAMdf[WascoERAMAMdf.height==54]['wind speed']
WascoERAWSMAM[:,7]=WascoERAMAMdf[WascoERAMAMdf.height==79]['wind speed']
WascoERAWSMAM[:,6]=WascoERAMAMdf[WascoERAMAMdf.height==106]['wind speed']
WascoERAWSMAM[:,5]=WascoERAMAMdf[WascoERAMAMdf.height==137]['wind speed']
WascoERAWSMAM[:,4]=WascoERAMAMdf[WascoERAMAMdf.height==170]['wind speed']
WascoERAWSMAM[:,3]=WascoERAMAMdf[WascoERAMAMdf.height==205]['wind speed']
WascoERAWSMAM[:,2]=WascoERAMAMdf[WascoERAMAMdf.height==245]['wind speed']
WascoERAWSMAM[:,1]=WascoERAMAMdf[WascoERAMAMdf.height==288]['wind speed']
WascoERAWSMAM[:,0]=WascoERAMAMdf[WascoERAMAMdf.height==334]['wind speed']

# creating summer ERA5 array
WascoERAJJAdf=WascoERAdf[(WascoERAdf.index.str.contains('-06-'))|(WascoERAdf.index.str.contains('-07-'))|(WascoERAdf.index.str.contains('-08-'))]
WascoERAWSJJA=np.zeros((2208,11))
WascoERAWSJJA[:,10]=WascoERAJJAdf[WascoERAJJAdf.height==10]['wind speed']
WascoERAWSJJA[:,9]=WascoERAJJAdf[WascoERAJJAdf.height==31]['wind speed']
WascoERAWSJJA[:,8]=WascoERAJJAdf[WascoERAJJAdf.height==54]['wind speed']
WascoERAWSJJA[:,7]=WascoERAJJAdf[WascoERAJJAdf.height==79]['wind speed']
WascoERAWSJJA[:,6]=WascoERAJJAdf[WascoERAJJAdf.height==106]['wind speed']
WascoERAWSJJA[:,5]=WascoERAJJAdf[WascoERAJJAdf.height==137]['wind speed']
WascoERAWSJJA[:,4]=WascoERAJJAdf[WascoERAJJAdf.height==170]['wind speed']
WascoERAWSJJA[:,3]=WascoERAJJAdf[WascoERAJJAdf.height==205]['wind speed']
WascoERAWSJJA[:,2]=WascoERAJJAdf[WascoERAJJAdf.height==245]['wind speed']
WascoERAWSJJA[:,1]=WascoERAJJAdf[WascoERAJJAdf.height==288]['wind speed']
WascoERAWSJJA[:,0]=WascoERAJJAdf[WascoERAJJAdf.height==334]['wind speed']

# creating fall ERA5 array
WascoERASONdf=WascoERAdf[(WascoERAdf.index.str.contains('-09-'))|(WascoERAdf.index.str.contains('-10-'))|(WascoERAdf.index.str.contains('-11-'))]
WascoERAWSSON=np.zeros((2184,11))
WascoERAWSSON[:,10]=WascoERASONdf[WascoERASONdf.height==10]['wind speed']
WascoERAWSSON[:,9]=WascoERASONdf[WascoERASONdf.height==31]['wind speed']
WascoERAWSSON[:,8]=WascoERASONdf[WascoERASONdf.height==54]['wind speed']
WascoERAWSSON[:,7]=WascoERASONdf[WascoERASONdf.height==79]['wind speed']
WascoERAWSSON[:,6]=WascoERASONdf[WascoERASONdf.height==106]['wind speed']
WascoERAWSSON[:,5]=WascoERASONdf[WascoERASONdf.height==137]['wind speed']
WascoERAWSSON[:,4]=WascoERASONdf[WascoERASONdf.height==170]['wind speed']
WascoERAWSSON[:,3]=WascoERASONdf[WascoERASONdf.height==205]['wind speed']
WascoERAWSSON[:,2]=WascoERASONdf[WascoERASONdf.height==245]['wind speed']
WascoERAWSSON[:,1]=WascoERASONdf[WascoERASONdf.height==288]['wind speed']
WascoERAWSSON[:,0]=WascoERASONdf[WascoERASONdf.height==334]['wind speed']

# %%
# creating dataframe for ERA diurnal cycle using height of 106
WascoERAdiurnal=WascoERAdf[WascoERAdf.height==106][['wind speed']].copy()
WascoERAdiurnal.index=pd.to_datetime(WascoERAdiurnal.index)
WascoERAdiurnal=WascoERAdiurnal.groupby(WascoERAdiurnal.index.hour).mean()

WascoERAdiurnalStd=WascoERAdf[WascoERAdf.height==106][['wind speed']].copy()
WascoERAdiurnalStd.index=pd.to_datetime(WascoERAdiurnalStd.index)
WascoERAdiurnalStd=WascoERAdiurnalStd.groupby(WascoERAdiurnalStd.index.hour).std()

# creating dataframes for winter diurnal cycle
WascoERADJFdiurnal=WascoERADJFdf[WascoERADJFdf.height==106][['wind speed']].copy()
WascoERADJFdiurnal.index=pd.to_datetime(WascoERADJFdiurnal.index)
WascoERADJFdiurnal=WascoERADJFdiurnal.groupby(WascoERADJFdiurnal.index.hour).mean()

WascoERADJFdiurnalStd=WascoERADJFdf[WascoERADJFdf.height==106][['wind speed']].copy()
WascoERADJFdiurnalStd.index=pd.to_datetime(WascoERADJFdiurnalStd.index)
WascoERADJFdiurnalStd=WascoERADJFdiurnalStd.groupby(WascoERADJFdiurnalStd.index.hour).std()

# creating dataframes for spring diurnal cycle
WascoERAMAMdiurnal=WascoERAMAMdf[WascoERAMAMdf.height==106][['wind speed']].copy()
WascoERAMAMdiurnal.index=pd.to_datetime(WascoERAMAMdiurnal.index)
WascoERAMAMdiurnal=WascoERAMAMdiurnal.groupby(WascoERAMAMdiurnal.index.hour).mean()

WascoERAMAMdiurnalStd=WascoERAMAMdf[WascoERAMAMdf.height==106][['wind speed']].copy()
WascoERAMAMdiurnalStd.index=pd.to_datetime(WascoERAMAMdiurnalStd.index)
WascoERAMAMdiurnalStd=WascoERAMAMdiurnalStd.groupby(WascoERAMAMdiurnalStd.index.hour).std()

# creating dataframes for summer dirunal cycle 
WascoERAJJAdiurnal=WascoERAJJAdf[WascoERAJJAdf.height==106][['wind speed']].copy()
WascoERAJJAdiurnal.index=pd.to_datetime(WascoERAJJAdiurnal.index)
WascoERAJJAdiurnal=WascoERAJJAdiurnal.groupby(WascoERAJJAdiurnal.index.hour).mean()

WascoERAJJAdiurnalStd=WascoERAJJAdf[WascoERAJJAdf.height==106][['wind speed']].copy()
WascoERAJJAdiurnalStd.index=pd.to_datetime(WascoERAJJAdiurnalStd.index)
WascoERAJJAdiurnalStd=WascoERAJJAdiurnalStd.groupby(WascoERAJJAdiurnalStd.index.hour).std()

# creating dataframes for fall diurnal cycle
WascoERASONdiurnal=WascoERASONdf[WascoERASONdf.height==106][['wind speed']].copy()
WascoERASONdiurnal.index=pd.to_datetime(WascoERASONdiurnal.index)
WascoERASONdiurnal=WascoERASONdiurnal.groupby(WascoERASONdiurnal.index.hour).mean()

WascoERASONdiurnalStd=WascoERASONdf[WascoERASONdf.height==106][['wind speed']].copy()
WascoERASONdiurnalStd.index=pd.to_datetime(WascoERASONdiurnalStd.index)
WascoERASONdiurnalStd=WascoERASONdiurnalStd.groupby(WascoERASONdiurnalStd.index.hour).std()

# %%
# Wasco WRF

# reading in WRF data
WascoWRFdf=pd.read_csv('/projects/sebu3651/ProjectResearch/Wasco/WascoWRF/WascoWRF')
WascoWRFdf.set_index('time',inplace=True)

# filtering WRF data to match observational period 
WascoWRFdf=WascoWRFdf[(WascoWRFdf.index >='2016-02-01 00:00:00')&(WascoWRFdf.index<='2017-02-01 00:00:00') ]

# create array of zeros and fill for each WRF height
WascoWRFWS=np.zeros((8784,8))
WascoWRFWS[:,0]=WascoWRFdf['windspeed_60m']
WascoWRFWS[:,1]=WascoWRFdf['windspeed_80m']
WascoWRFWS[:,2]=WascoWRFdf['windspeed_100m']
WascoWRFWS[:,3]=WascoWRFdf['windspeed_120m']
WascoWRFWS[:,4]=WascoWRFdf['windspeed_140m']
WascoWRFWS[:,5]=WascoWRFdf['windspeed_160m']
WascoWRFWS[:,6]=WascoWRFdf['windspeed_180m']
WascoWRFWS[:,7]=WascoWRFdf['windspeed_200m']

# z values for WRF heights
WascoWRFZ=[60.,80.,100.,120.,140.,160.,180.,200.]

# %%
# creating winter WRF array 
WascoWRFDJFdf=WascoWRFdf[(WascoWRFdf.index.str.contains('-12-'))|(WascoWRFdf.index.str.contains('-01-'))|(WascoWRFdf.index.str.contains('-02-'))]
WascoWRFWSDJF=np.zeros((2184,8))
WascoWRFWSDJF[:,0]=WascoWRFDJFdf['windspeed_60m']
WascoWRFWSDJF[:,1]=WascoWRFDJFdf['windspeed_80m']
WascoWRFWSDJF[:,2]=WascoWRFDJFdf['windspeed_100m']
WascoWRFWSDJF[:,3]=WascoWRFDJFdf['windspeed_120m']
WascoWRFWSDJF[:,4]=WascoWRFDJFdf['windspeed_140m']
WascoWRFWSDJF[:,5]=WascoWRFDJFdf['windspeed_160m']
WascoWRFWSDJF[:,6]=WascoWRFDJFdf['windspeed_180m']
WascoWRFWSDJF[:,7]=WascoWRFDJFdf['windspeed_200m']

# creating spring WRF array 
WascoWRFMAMdf=WascoWRFdf[(WascoWRFdf.index.str.contains('-03-'))|(WascoWRFdf.index.str.contains('-04-'))|(WascoWRFdf.index.str.contains('-05-'))]
WascoWRFWSMAM=np.zeros((2208,8))
WascoWRFWSMAM[:,0]=WascoWRFMAMdf['windspeed_60m']
WascoWRFWSMAM[:,1]=WascoWRFMAMdf['windspeed_80m']
WascoWRFWSMAM[:,2]=WascoWRFMAMdf['windspeed_100m']
WascoWRFWSMAM[:,3]=WascoWRFMAMdf['windspeed_120m']
WascoWRFWSMAM[:,4]=WascoWRFMAMdf['windspeed_140m']
WascoWRFWSMAM[:,5]=WascoWRFMAMdf['windspeed_160m']
WascoWRFWSMAM[:,6]=WascoWRFMAMdf['windspeed_180m']
WascoWRFWSMAM[:,7]=WascoWRFMAMdf['windspeed_200m']

# creating summer WRF array 
WascoWRFJJAdf=WascoWRFdf[(WascoWRFdf.index.str.contains('-06-'))|(WascoWRFdf.index.str.contains('-07-'))|(WascoWRFdf.index.str.contains('-08-'))]
WascoWRFWSJJA=np.zeros((2208,8))
WascoWRFWSJJA[:,0]=WascoWRFJJAdf['windspeed_60m']
WascoWRFWSJJA[:,1]=WascoWRFJJAdf['windspeed_80m']
WascoWRFWSJJA[:,2]=WascoWRFJJAdf['windspeed_100m']
WascoWRFWSJJA[:,3]=WascoWRFJJAdf['windspeed_120m']
WascoWRFWSJJA[:,4]=WascoWRFJJAdf['windspeed_140m']
WascoWRFWSJJA[:,5]=WascoWRFJJAdf['windspeed_160m']
WascoWRFWSJJA[:,6]=WascoWRFJJAdf['windspeed_180m']
WascoWRFWSJJA[:,7]=WascoWRFJJAdf['windspeed_200m']

# creating fall WRF array 
WascoWRFSONdf=WascoWRFdf[(WascoWRFdf.index.str.contains('-09-'))|(WascoWRFdf.index.str.contains('-10-'))|(WascoWRFdf.index.str.contains('-11-'))]
WascoWRFWSSON=np.zeros((2184,8))
WascoWRFWSSON[:,0]=WascoWRFSONdf['windspeed_60m']
WascoWRFWSSON[:,1]=WascoWRFSONdf['windspeed_80m']
WascoWRFWSSON[:,2]=WascoWRFSONdf['windspeed_100m']
WascoWRFWSSON[:,3]=WascoWRFSONdf['windspeed_120m']
WascoWRFWSSON[:,4]=WascoWRFSONdf['windspeed_140m']
WascoWRFWSSON[:,5]=WascoWRFSONdf['windspeed_160m']
WascoWRFWSSON[:,6]=WascoWRFSONdf['windspeed_180m']
WascoWRFWSSON[:,7]=WascoWRFSONdf['windspeed_200m']

# %%
# creating dataframe of overall WRF diurnal cycle using height of 100
WascoWRFdiurnal=WascoWRFdf[['windspeed_100m']].copy()
WascoWRFdiurnal.index=pd.to_datetime(WascoWRFdiurnal.index)
WascoWRFdiurnal=WascoWRFdiurnal.groupby(WascoWRFdiurnal.index.hour).mean()

WascoWRFdiurnalStd=WascoWRFdf[['windspeed_100m']].copy()
WascoWRFdiurnalStd.index=pd.to_datetime(WascoWRFdiurnalStd.index)
WascoWRFdiurnalStd=WascoWRFdiurnalStd.groupby(WascoWRFdiurnalStd.index.hour).std()

# creating dataframes for winter diurnal cycle
WascoWRFDJFdiurnal=WascoWRFDJFdf[['windspeed_100m']].copy()
WascoWRFDJFdiurnal.index=pd.to_datetime(WascoWRFDJFdiurnal.index)
WascoWRFDJFdiurnal=WascoWRFDJFdiurnal.groupby(WascoWRFDJFdiurnal.index.hour).mean()

WascoWRFDJFdiurnalStd=WascoWRFDJFdf[['windspeed_100m']].copy()
WascoWRFDJFdiurnalStd.index=pd.to_datetime(WascoWRFDJFdiurnalStd.index)
WascoWRFDJFdiurnalStd=WascoWRFDJFdiurnalStd.groupby(WascoWRFDJFdiurnalStd.index.hour).std()

# creating dataframes for spring diurnal cycle
WascoWRFMAMdiurnal=WascoWRFMAMdf[['windspeed_100m']].copy()
WascoWRFMAMdiurnal.index=pd.to_datetime(WascoWRFMAMdiurnal.index)
WascoWRFMAMdiurnal=WascoWRFMAMdiurnal.groupby(WascoWRFMAMdiurnal.index.hour).mean()

WascoWRFMAMdiurnalStd=WascoWRFMAMdf[['windspeed_100m']].copy()
WascoWRFMAMdiurnalStd.index=pd.to_datetime(WascoWRFMAMdiurnalStd.index)
WascoWRFMAMdiurnalStd=WascoWRFMAMdiurnalStd.groupby(WascoWRFMAMdiurnalStd.index.hour).std()

# creating dataframes for summer diurnal cycle
WascoWRFJJAdiurnal=WascoWRFJJAdf[['windspeed_100m']].copy()
WascoWRFJJAdiurnal.index=pd.to_datetime(WascoWRFJJAdiurnal.index)
WascoWRFJJAdiurnal=WascoWRFJJAdiurnal.groupby(WascoWRFJJAdiurnal.index.hour).mean()

WascoWRFJJAdiurnalStd=WascoWRFJJAdf[['windspeed_100m']].copy()
WascoWRFJJAdiurnalStd.index=pd.to_datetime(WascoWRFJJAdiurnalStd.index)
WascoWRFJJAdiurnalStd=WascoWRFJJAdiurnalStd.groupby(WascoWRFJJAdiurnalStd.index.hour).std()

# creating dataframes for fall diurnal cycle
WascoWRFSONdiurnal=WascoWRFSONdf[['windspeed_100m']].copy()
WascoWRFSONdiurnal.index=pd.to_datetime(WascoWRFSONdiurnal.index)
WascoWRFSONdiurnal=WascoWRFSONdiurnal.groupby(WascoWRFSONdiurnal.index.hour).mean()

WascoWRFSONdiurnalStd=WascoWRFSONdf[['windspeed_100m']].copy()
WascoWRFSONdiurnalStd.index=pd.to_datetime(WascoWRFSONdiurnalStd.index)
WascoWRFSONdiurnalStd=WascoWRFSONdiurnalStd.groupby(WascoWRFSONdiurnalStd.index.hour).std()

# %%
# Wasco MERRA2

# reading in MERRA2 data
WascoMERRAdf=pd.read_csv('/projects/sebu3651/ProjectResearch/Wasco/WascoMERRA2/WascoMERRA2')
WascoMERRAdf.set_index('time',inplace=True)

# filtering MERRA2 to match observational period
WascoMERRAdf=WascoMERRAdf[(WascoMERRAdf.index >='2016-01-31 23:00:00')&(WascoMERRAdf.index<='2017-01-31 23:00:00') ]

# create array of zeros and fill for each MERRA2 height
WascoMERRAWS=np.zeros((8784,6))
WascoMERRAWS[:,0]=WascoMERRAdf['40m wind speed']
WascoMERRAWS[:,1]=WascoMERRAdf['60m wind speed']
WascoMERRAWS[:,2]=WascoMERRAdf['80m wind speed']
WascoMERRAWS[:,3]=WascoMERRAdf['100m wind speed']
WascoMERRAWS[:,4]=WascoMERRAdf['120m wind speed']
WascoMERRAWS[:,5]=WascoMERRAdf['140m wind speed']

# list of z values for MERRA2 heights
WascoMERRAZ=[40,60,80,100,120,140]

# %%
# creating winter MERRA2 array
WascoMERRADJFdf=WascoMERRAdf[(WascoMERRAdf.index.str.contains('-12-'))|(WascoMERRAdf.index.str.contains('-01-'))|(WascoMERRAdf.index.str.contains('-02-'))]
WascoMERRAWSDJF=np.zeros((2184,6))
WascoMERRAWSDJF[:,0]=WascoMERRADJFdf['40m wind speed']
WascoMERRAWSDJF[:,1]=WascoMERRADJFdf['60m wind speed']
WascoMERRAWSDJF[:,2]=WascoMERRADJFdf['80m wind speed']
WascoMERRAWSDJF[:,3]=WascoMERRADJFdf['100m wind speed']
WascoMERRAWSDJF[:,4]=WascoMERRADJFdf['120m wind speed']
WascoMERRAWSDJF[:,5]=WascoMERRADJFdf['140m wind speed']

# creating spring MERRA2 array
WascoMERRAMAMdf=WascoMERRAdf[(WascoMERRAdf.index.str.contains('-03-'))|(WascoMERRAdf.index.str.contains('-04-'))|(WascoMERRAdf.index.str.contains('-05-'))]
WascoMERRAWSMAM=np.zeros((2208,6))
WascoMERRAWSMAM[:,0]=WascoMERRAMAMdf['40m wind speed']
WascoMERRAWSMAM[:,1]=WascoMERRAMAMdf['60m wind speed']
WascoMERRAWSMAM[:,2]=WascoMERRAMAMdf['80m wind speed']
WascoMERRAWSMAM[:,3]=WascoMERRAMAMdf['100m wind speed']
WascoMERRAWSMAM[:,4]=WascoMERRAMAMdf['120m wind speed']
WascoMERRAWSMAM[:,5]=WascoMERRAMAMdf['140m wind speed']

# creating summer MERRA2 array
WascoMERRAJJAdf=WascoMERRAdf[(WascoMERRAdf.index.str.contains('-06-'))|(WascoMERRAdf.index.str.contains('-07-'))|(WascoMERRAdf.index.str.contains('-08-'))]
WascoMERRAWSJJA=np.zeros((2208,6))
WascoMERRAWSJJA[:,0]=WascoMERRAJJAdf['40m wind speed']
WascoMERRAWSJJA[:,1]=WascoMERRAJJAdf['60m wind speed']
WascoMERRAWSJJA[:,2]=WascoMERRAJJAdf['80m wind speed']
WascoMERRAWSJJA[:,3]=WascoMERRAJJAdf['100m wind speed']
WascoMERRAWSJJA[:,4]=WascoMERRAJJAdf['120m wind speed']
WascoMERRAWSJJA[:,5]=WascoMERRAJJAdf['140m wind speed']

# creating fall MERRA2 array
WascoMERRASONdf=WascoMERRAdf[(WascoMERRAdf.index.str.contains('-09-'))|(WascoMERRAdf.index.str.contains('-10-'))|(WascoMERRAdf.index.str.contains('-11-'))]
WascoMERRAWSSON=np.zeros((2184,6))
WascoMERRAWSSON[:,0]=WascoMERRASONdf['40m wind speed']
WascoMERRAWSSON[:,1]=WascoMERRASONdf['60m wind speed']
WascoMERRAWSSON[:,2]=WascoMERRASONdf['80m wind speed']
WascoMERRAWSSON[:,3]=WascoMERRASONdf['100m wind speed']
WascoMERRAWSSON[:,4]=WascoMERRASONdf['120m wind speed']
WascoMERRAWSSON[:,5]=WascoMERRASONdf['140m wind speed']

# %%
# creating dataframe of overall MERRA2 diurnal cycle using height of 100
WascoMERRAdiurnal=WascoMERRAdf[['100m wind speed']].copy()
WascoMERRAdiurnal.index=pd.to_datetime(WascoMERRAdiurnal.index)
WascoMERRAdiurnal=WascoMERRAdiurnal.groupby(WascoMERRAdiurnal.index.hour).mean()

WascoMERRAdiurnalStd=WascoMERRAdf[['100m wind speed']].copy()
WascoMERRAdiurnalStd.index=pd.to_datetime(WascoMERRAdiurnalStd.index)
WascoMERRAdiurnalStd=WascoMERRAdiurnalStd.groupby(WascoMERRAdiurnalStd.index.hour).std()

# creating dataframes for winter diurnal cycle
WascoMERRADJFdiurnal=WascoMERRADJFdf[['100m wind speed']].copy()
WascoMERRADJFdiurnal.index=pd.to_datetime(WascoMERRADJFdiurnal.index)
WascoMERRADJFdiurnal=WascoMERRADJFdiurnal.groupby(WascoMERRADJFdiurnal.index.hour).mean()

WascoMERRADJFdiurnalStd=WascoMERRADJFdf[['100m wind speed']].copy()
WascoMERRADJFdiurnalStd.index=pd.to_datetime(WascoMERRADJFdiurnalStd.index)
WascoMERRADJFdiurnalStd=WascoMERRADJFdiurnalStd.groupby(WascoMERRADJFdiurnalStd.index.hour).std()

# creating dataframes for spring diurnal cycle
WascoMERRAMAMdiurnal=WascoMERRAMAMdf[['100m wind speed']].copy()
WascoMERRAMAMdiurnal.index=pd.to_datetime(WascoMERRAMAMdiurnal.index)
WascoMERRAMAMdiurnal=WascoMERRAMAMdiurnal.groupby(WascoMERRAMAMdiurnal.index.hour).mean()

WascoMERRAMAMdiurnalStd=WascoMERRAMAMdf[['100m wind speed']].copy()
WascoMERRAMAMdiurnalStd.index=pd.to_datetime(WascoMERRAMAMdiurnalStd.index)
WascoMERRAMAMdiurnalStd=WascoMERRAMAMdiurnalStd.groupby(WascoMERRAMAMdiurnalStd.index.hour).std()

# creating dataframes for summer diurnal cycle 
WascoMERRAJJAdiurnal=WascoMERRAJJAdf[['100m wind speed']].copy()
WascoMERRAJJAdiurnal.index=pd.to_datetime(WascoMERRAJJAdiurnal.index)
WascoMERRAJJAdiurnal=WascoMERRAJJAdiurnal.groupby(WascoMERRAJJAdiurnal.index.hour).mean()

WascoMERRAJJAdiurnalStd=WascoMERRAJJAdf[['100m wind speed']].copy()
WascoMERRAJJAdiurnalStd.index=pd.to_datetime(WascoMERRAJJAdiurnalStd.index)
WascoMERRAJJAdiurnalStd=WascoMERRAJJAdiurnalStd.groupby(WascoMERRAJJAdiurnalStd.index.hour).std()

# creating dataframes for fall diurnal cycle
WascoMERRASONdiurnal=WascoMERRASONdf[['100m wind speed']].copy()
WascoMERRASONdiurnal.index=pd.to_datetime(WascoMERRASONdiurnal.index)
WascoMERRASONdiurnal=WascoMERRASONdiurnal.groupby(WascoMERRASONdiurnal.index.hour).mean()

WascoMERRASONdiurnalStd=WascoMERRASONdf[['100m wind speed']].copy()
WascoMERRASONdiurnalStd.index=pd.to_datetime(WascoMERRASONdiurnalStd.index)
WascoMERRASONdiurnalStd=WascoMERRASONdiurnalStd.groupby(WascoMERRASONdiurnalStd.index.hour).std()

# %%
# Wasco Lidar

# reading in data
WascoLidardf=pd.read_csv('/projects/sebu3651/ProjectResearch/Wasco/WascoLidar/WascoLidarInterpolatedHourly')
WascoLidardf.set_index('Date',inplace=True)

# filtering data to match desired observational period
WascoLidardf=WascoLidardf[(WascoLidardf.index<='2017-01-31 23:00:00') & (WascoLidardf.index>='2016-02-01 00:00:00')]

# creating an array of zeros and filling for each observational height
WascoLidarWS=np.zeros((8784,9))
WascoLidarWS[:,0]=WascoLidardf['40m'].values
WascoLidarWS[:,1]=WascoLidardf['60m'].values
WascoLidarWS[:,2]=WascoLidardf['80m'].values
WascoLidarWS[:,3]=WascoLidardf['100m'].values
WascoLidarWS[:,4]=WascoLidardf['120m'].values
WascoLidarWS[:,5]=WascoLidardf['140m'].values
WascoLidarWS[:,6]=WascoLidardf['160m'].values
WascoLidarWS[:,7]=WascoLidardf['180m'].values
WascoLidarWS[:,8]=WascoLidardf['200m'].values

# z values for lidar
WascoLidarZ=[40.,60.,80.,100.,120.,140.,160.,180.,200.]

# %%
# creating winter lidar array
WascoLidarDJFdf=WascoLidardf[(WascoLidardf.index.str.contains('-12-'))|(WascoLidardf.index.str.contains('-01-'))|(WascoLidardf.index.str.contains('-02-'))]
WascoLidarWSDJF=np.zeros((2184,9))
WascoLidarWSDJF[:,0]=WascoLidarDJFdf['40m'].values
WascoLidarWSDJF[:,1]=WascoLidarDJFdf['60m'].values
WascoLidarWSDJF[:,2]=WascoLidarDJFdf['80m'].values
WascoLidarWSDJF[:,3]=WascoLidarDJFdf['100m'].values
WascoLidarWSDJF[:,4]=WascoLidarDJFdf['120m'].values
WascoLidarWSDJF[:,5]=WascoLidarDJFdf['140m'].values
WascoLidarWSDJF[:,6]=WascoLidarDJFdf['160m'].values
WascoLidarWSDJF[:,7]=WascoLidarDJFdf['180m'].values
WascoLidarWSDJF[:,8]=WascoLidarDJFdf['200m'].values

# creating spring lidar array
WascoLidarMAMdf=WascoLidardf[(WascoLidardf.index.str.contains('-03-'))|(WascoLidardf.index.str.contains('-04-'))|(WascoLidardf.index.str.contains('-05-'))]
WascoLidarWSMAM=np.zeros((2208,9))
WascoLidarWSMAM[:,0]=WascoLidarMAMdf['40m'].values
WascoLidarWSMAM[:,1]=WascoLidarMAMdf['60m'].values
WascoLidarWSMAM[:,2]=WascoLidarMAMdf['80m'].values
WascoLidarWSMAM[:,3]=WascoLidarMAMdf['100m'].values
WascoLidarWSMAM[:,4]=WascoLidarMAMdf['120m'].values
WascoLidarWSMAM[:,5]=WascoLidarMAMdf['140m'].values
WascoLidarWSMAM[:,6]=WascoLidarMAMdf['160m'].values
WascoLidarWSMAM[:,7]=WascoLidarMAMdf['180m'].values
WascoLidarWSMAM[:,8]=WascoLidarMAMdf['200m'].values

# creating summer lidar array
WascoLidarJJAdf=WascoLidardf[(WascoLidardf.index.str.contains('-06-'))|(WascoLidardf.index.str.contains('-07-'))|(WascoLidardf.index.str.contains('-08-'))]
WascoLidarWSJJA=np.zeros((2208,9))
WascoLidarWSJJA[:,0]=WascoLidarJJAdf['40m'].values
WascoLidarWSJJA[:,1]=WascoLidarJJAdf['60m'].values
WascoLidarWSJJA[:,2]=WascoLidarJJAdf['80m'].values
WascoLidarWSJJA[:,3]=WascoLidarJJAdf['100m'].values
WascoLidarWSJJA[:,4]=WascoLidarJJAdf['120m'].values
WascoLidarWSJJA[:,5]=WascoLidarJJAdf['140m'].values
WascoLidarWSJJA[:,6]=WascoLidarJJAdf['160m'].values
WascoLidarWSJJA[:,7]=WascoLidarJJAdf['180m'].values
WascoLidarWSJJA[:,8]=WascoLidarJJAdf['200m'].values

# creating fall lidar array
WascoLidarSONdf=WascoLidardf[(WascoLidardf.index.str.contains('-09-'))|(WascoLidardf.index.str.contains('-10-'))|(WascoLidardf.index.str.contains('-11-'))]
WascoLidarWSSON=np.zeros((2184,9))
WascoLidarWSSON[:,0]=WascoLidarSONdf['40m'].values
WascoLidarWSSON[:,1]=WascoLidarSONdf['60m'].values
WascoLidarWSSON[:,2]=WascoLidarSONdf['80m'].values
WascoLidarWSSON[:,3]=WascoLidarSONdf['100m'].values
WascoLidarWSSON[:,4]=WascoLidarSONdf['120m'].values
WascoLidarWSSON[:,5]=WascoLidarSONdf['140m'].values
WascoLidarWSSON[:,6]=WascoLidarSONdf['160m'].values
WascoLidarWSSON[:,7]=WascoLidarSONdf['180m'].values
WascoLidarWSSON[:,8]=WascoLidarSONdf['200m'].values

# %%
# creating dataframe of overall lidar diurnal cycle using 100m height
WascoLidardiurnal=WascoLidardf['100m']
WascoLidardiurnal.index=pd.to_datetime(WascoLidardiurnal.index)
WascoLidardiurnal=WascoLidardiurnal.groupby(WascoLidardiurnal.index.hour).mean()

WascoLidardiurnalStd=WascoLidardf['100m']
WascoLidardiurnalStd.index=pd.to_datetime(WascoLidardiurnalStd.index)
WascoLidardiurnalStd=WascoLidardiurnalStd.groupby(WascoLidardiurnalStd.index.hour).std()

# creating dataframes for winter diurnal cycle
WascoLidarDJFdiurnal=WascoLidarDJFdf['100m']
WascoLidarDJFdiurnal.index=pd.to_datetime(WascoLidarDJFdiurnal.index)
WascoLidarDJFdiurnal=WascoLidarDJFdiurnal.groupby(WascoLidarDJFdiurnal.index.hour).mean()

WascoLidardiurnalDJFStd=WascoLidarDJFdf['100m']
WascoLidardiurnalDJFStd.index=pd.to_datetime(WascoLidardiurnalDJFStd.index)
WascoLidardiurnalDJFStd=WascoLidardiurnalDJFStd.groupby(WascoLidardiurnalDJFStd.index.hour).std()

# creating dataframes for spring diurnal cycle 
WascoLidarMAMdiurnal=WascoLidarMAMdf['100m']
WascoLidarMAMdiurnal.index=pd.to_datetime(WascoLidarMAMdiurnal.index)
WascoLidarMAMdiurnal=WascoLidarMAMdiurnal.groupby(WascoLidarMAMdiurnal.index.hour).mean()

WascoLidardiurnalMAMStd=WascoLidarMAMdf['100m']
WascoLidardiurnalMAMStd.index=pd.to_datetime(WascoLidardiurnalMAMStd.index)
WascoLidardiurnalMAMStd=WascoLidardiurnalMAMStd.groupby(WascoLidardiurnalMAMStd.index.hour).std()

# creating dataframes for summer diurnal cycle
WascoLidarJJAdiurnal=WascoLidarJJAdf['100m']
WascoLidarJJAdiurnal.index=pd.to_datetime(WascoLidarJJAdiurnal.index)
WascoLidarJJAdiurnal=WascoLidarJJAdiurnal.groupby(WascoLidarJJAdiurnal.index.hour).mean()

WascoLidardiurnalJJAStd=WascoLidarJJAdf['100m']
WascoLidardiurnalJJAStd.index=pd.to_datetime(WascoLidardiurnalJJAStd.index)
WascoLidardiurnalJJAStd=WascoLidardiurnalJJAStd.groupby(WascoLidardiurnalJJAStd.index.hour).std()

# creating dataframes for fall diurnal cycle
WascoLidarSONdiurnal=WascoLidarSONdf['100m']
WascoLidarSONdiurnal.index=pd.to_datetime(WascoLidarSONdiurnal.index)
WascoLidarSONdiurnal=WascoLidarSONdiurnal.groupby(WascoLidarSONdiurnal.index.hour).mean()

WascoLidardiurnalSONStd=WascoLidarSONdf['100m']
WascoLidardiurnalSONStd.index=pd.to_datetime(WascoLidardiurnalSONStd.index)
WascoLidardiurnalSONStd=WascoLidardiurnalSONStd.groupby(WascoLidardiurnalSONStd.index.hour).std()

# %%
# Wasco Total Mean Wind Profile

# calculation of overall mean values for each dataset
WascoERAWSMean=WascoERAWS.mean(axis=0)
WascoWRFWSMean=WascoWRFWS.mean(axis=0)
WascoMERRAWSMean=WascoMERRAWS.mean(axis=0)
WascoLidarWSMean=np.nanmean(WascoLidarWS,axis=0)

# calculation of overall standard deviation values for each dataset
WascoERAWSStd=WascoERAWS.std(axis=0)
WascoWRFWSStd=WascoWRFWS.std(axis=0)
WascoMERRAWSStd=WascoMERRAWS.std(axis=0)
WascoLidarWSStd=np.nanstd(WascoLidarWS,axis=0)

plt.figure()

plt.plot(WascoERAWSMean,WascoERAZ,label='ERA-5',color='orange')
plt.plot(WascoWRFWSMean,WascoWRFZ,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAWSMean,WascoMERRAZ,label='MERRA-2',color='green')
plt.plot(WascoLidarWSMean,WascoLidarZ,'--',color='black',label='Lidar')

plt.fill_betweenx(WascoERAZ,WascoERAWSMean-WascoERAWSStd,WascoERAWSMean+WascoERAWSStd,alpha=0.1,color='orange')
plt.fill_betweenx(WascoWRFZ,WascoWRFWSMean-WascoWRFWSStd,WascoWRFWSMean+WascoWRFWSStd,alpha=0.1,color='blue')
plt.fill_betweenx(WascoMERRAZ,WascoMERRAWSMean-WascoMERRAWSStd,WascoMERRAWSMean+WascoMERRAWSStd,alpha=0.1,color='green')
plt.fill_betweenx(WascoLidarZ,WascoLidarWSMean-WascoLidarWSStd,WascoLidarWSMean+WascoLidarWSStd,alpha=0.1,color='black')

plt.legend(fontsize=12)
plt.xlabel('Mean wind speed (m/s)', fontsize=12)
plt.ylabel('Height (m)')
plt.ylim([60,140])
plt.xlim([0,16.5])
# plt.savefig('WascoMeanTotal')
plt.show()

# %%
# Wasco Mean Wind Profile DJF

WascoERAWSDJFMean=WascoERAWSDJF.mean(axis=0)
WascoWRFWSDJFMean=WascoWRFWSDJF.mean(axis=0)
WascoMERRAWSDJFMean=WascoMERRAWSDJF.mean(axis=0)
WascoLidarWSDJFMean=np.nanmean(WascoLidarWSDJF,axis=0)

WascoERAWSDJFStd=WascoERAWSDJF.std(axis=0)
WascoWRFWSDJFStd=WascoWRFWSDJF.std(axis=0)
WascoMERRAWSDJFStd=WascoMERRAWSDJF.std(axis=0)
WascoLidarWSDJFStd=np.nanstd(WascoLidarWSDJF,axis=0)

plt.figure()

plt.plot(WascoERAWSDJFMean,WascoERAZ,label='ERA5',color='orange')
plt.plot(WascoWRFWSDJFMean,WascoWRFZ,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAWSDJFMean,WascoMERRAZ,label='MERRA2',color='green')
plt.plot(WascoLidarWSDJFMean,WascoLidarZ,'--',color='black',label='Lidar')

plt.fill_betweenx(WascoERAZ,WascoERAWSDJFMean-WascoERAWSDJFStd,WascoERAWSDJFMean+WascoERAWSDJFStd,alpha=0.1,color='orange')
plt.fill_betweenx(WascoWRFZ,WascoWRFWSDJFMean-WascoWRFWSDJFStd,WascoWRFWSDJFMean+WascoWRFWSDJFStd,alpha=0.1,color='blue')
plt.fill_betweenx(WascoMERRAZ,WascoMERRAWSDJFMean-WascoMERRAWSDJFStd,WascoMERRAWSDJFMean+WascoMERRAWSDJFStd,alpha=0.1,color='green')
plt.fill_betweenx(WascoLidarZ,WascoLidarWSDJFMean-WascoLidarWSDJFStd,WascoLidarWSDJFMean+WascoLidarWSDJFStd,alpha=0.1,color='black')

plt.legend(fontsize=12)
plt.xlabel('Winter mean wind speed (m/s)', fontsize=12)
plt.ylabel('Height (m)')
plt.ylim([60,140])
plt.xlim([0,16.5])
# plt.savefig('WascoMeanDJF')
plt.show()

# %%
# Wasco Mean Wind Profile MAM

WascoERAWSMAMMean=WascoERAWSMAM.mean(axis=0)
WascoWRFWSMAMMean=WascoWRFWSMAM.mean(axis=0)
WascoMERRAWSMAMMean=WascoMERRAWSMAM.mean(axis=0)
WascoLidarWSMAMMean=np.nanmean(WascoLidarWSMAM,axis=0)

WascoERAWSMAMStd=WascoERAWSMAM.std(axis=0)
WascoWRFWSMAMStd=WascoWRFWSMAM.std(axis=0)
WascoMERRAWSMAMStd=WascoMERRAWSMAM.std(axis=0)
WascoLidarWSMAMStd=np.nanstd(WascoLidarWSMAM,axis=0)

plt.figure()

plt.plot(WascoERAWSMAMMean,WascoERAZ,label='ERA5',color='orange')
plt.plot(WascoWRFWSMAMMean,WascoWRFZ,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAWSMAMMean,WascoMERRAZ,label='MERRA2',color='green')
plt.plot(WascoLidarWSMAMMean,WascoLidarZ,'--',color='black',label='Lidar')

plt.fill_betweenx(WascoERAZ,WascoERAWSMAMMean-WascoERAWSMAMStd,WascoERAWSMAMMean+WascoERAWSMAMStd,alpha=0.1,color='orange')
plt.fill_betweenx(WascoWRFZ,WascoWRFWSMAMMean-WascoWRFWSMAMStd,WascoWRFWSMAMMean+WascoWRFWSMAMStd,alpha=0.1,color='blue')
plt.fill_betweenx(WascoMERRAZ,WascoMERRAWSMAMMean-WascoMERRAWSMAMStd,WascoMERRAWSMAMMean+WascoMERRAWSMAMStd,alpha=0.1,color='green')
plt.fill_betweenx(WascoLidarZ,WascoLidarWSMAMMean-WascoLidarWSMAMStd,WascoLidarWSMAMMean+WascoLidarWSMAMStd,alpha=0.1,color='black')

plt.legend(fontsize=12)
plt.xlabel('Spring mean wind speed (m/s)', fontsize=12)
plt.ylabel('Height (m)')
plt.ylim([60,140])
plt.xlim([0,16.5])
# plt.savefig('WascoMeanMAM')
plt.show()

# %%
# Wasco Mean Wind Profile JJA

WascoERAWSJJAMean=WascoERAWSJJA.mean(axis=0)
WascoWRFWSJJAMean=WascoWRFWSJJA.mean(axis=0)
WascoMERRAWSJJAMean=WascoMERRAWSJJA.mean(axis=0)
WascoLidarWSJJAMean=np.nanmean(WascoLidarWSJJA,axis=0)

WascoERAWSJJAStd=WascoERAWSJJA.std(axis=0)
WascoWRFWSJJAStd=WascoWRFWSJJA.std(axis=0)
WascoMERRAWSJJAStd=WascoMERRAWSJJA.std(axis=0)
WascoLidarWSJJAStd=np.nanstd(WascoLidarWSJJA,axis=0)

plt.figure()

plt.plot(WascoERAWSJJAMean,WascoERAZ,label='ERA5',color='orange')
plt.plot(WascoWRFWSJJAMean,WascoWRFZ,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAWSJJAMean,WascoMERRAZ,label='MERRA2',color='green')
plt.plot(WascoLidarWSJJAMean,WascoLidarZ,'--',color='black',label='Lidar')

plt.fill_betweenx(WascoERAZ,WascoERAWSJJAMean-WascoERAWSJJAStd,WascoERAWSJJAMean+WascoERAWSJJAStd,alpha=0.1,color='orange')
plt.fill_betweenx(WascoWRFZ,WascoWRFWSJJAMean-WascoWRFWSJJAStd,WascoWRFWSJJAMean+WascoWRFWSJJAStd,alpha=0.1,color='blue')
plt.fill_betweenx(WascoMERRAZ,WascoMERRAWSJJAMean-WascoMERRAWSJJAStd,WascoMERRAWSJJAMean+WascoMERRAWSJJAStd,alpha=0.1,color='green')
plt.fill_betweenx(WascoLidarZ,WascoLidarWSJJAMean-WascoLidarWSJJAStd,WascoLidarWSJJAMean+WascoLidarWSJJAStd,alpha=0.1,color='black')

plt.legend(fontsize=12)
plt.xlabel('Summer mean wind speed (m/s)', fontsize=12)
plt.ylabel('Height (m)')
plt.ylim([60,140])
plt.xlim([0,16.5])
# plt.savefig('WascoMeanJJA')
plt.show()

# %%
# Wasco Mean Wind Profile SON

WascoERAWSSONMean=WascoERAWSSON.mean(axis=0)
WascoWRFWSSONMean=WascoWRFWSSON.mean(axis=0)
WascoMERRAWSSONMean=WascoMERRAWSSON.mean(axis=0)
WascoLidarWSSONMean=np.nanmean(WascoLidarWSSON,axis=0)

WascoERAWSSONStd=WascoERAWSSON.std(axis=0)
WascoWRFWSSONStd=WascoWRFWSSON.std(axis=0)
WascoMERRAWSSONStd=WascoMERRAWSSON.std(axis=0)
WascoLidarWSSONStd=np.nanstd(WascoLidarWSSON,axis=0)

plt.figure()

plt.plot(WascoERAWSSONMean,WascoERAZ,label='ERA5',color='orange')
plt.plot(WascoWRFWSSONMean,WascoWRFZ,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAWSSONMean,WascoMERRAZ,label='MERRA2',color='green')
plt.plot(WascoLidarWSSONMean,WascoLidarZ,'--',color='black',label='Lidar')

plt.fill_betweenx(WascoERAZ,WascoERAWSSONMean-WascoERAWSSONStd,WascoERAWSSONMean+WascoERAWSSONStd,alpha=0.1,color='orange')
plt.fill_betweenx(WascoWRFZ,WascoWRFWSSONMean-WascoWRFWSSONStd,WascoWRFWSSONMean+WascoWRFWSSONStd,alpha=0.1,color='blue')
plt.fill_betweenx(WascoMERRAZ,WascoMERRAWSSONMean-WascoMERRAWSSONStd,WascoMERRAWSSONMean+WascoMERRAWSSONStd,alpha=0.1,color='green')
plt.fill_betweenx(WascoLidarZ,WascoLidarWSSONMean-WascoLidarWSSONStd,WascoLidarWSSONMean+WascoLidarWSSONStd,alpha=0.1,color='black')

plt.legend(fontsize=12)
plt.xlabel('Fall mean wind speed (m/s)', fontsize=12)
plt.ylabel('Height (m)')
plt.ylim([60,140])
plt.xlim([0,16.5])
# plt.savefig('WascoMeanSON')
plt.show()

# %%
# Wasco Diurnal Cycle Total

plt.plot(WascoERAdiurnal, label='ERA-5',color='orange')
plt.plot(WascoWRFdiurnal,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAdiurnal,label='MERRA-2',color='green')
plt.plot(WascoLidardiurnal,'--',label='Lidar',color='black')

plt.fill_between(np.arange(0,24,1),WascoERAdiurnal['wind speed']-WascoERAdiurnalStd['wind speed'],WascoERAdiurnal['wind speed']+WascoERAdiurnalStd['wind speed'],alpha=0.1,color='orange')
plt.fill_between(np.arange(0,24,1),WascoWRFdiurnal.windspeed_100m-WascoWRFdiurnalStd.windspeed_100m,WascoWRFdiurnal.windspeed_100m+WascoWRFdiurnalStd.windspeed_100m,alpha=0.1,color='blue')
plt.fill_between(np.arange(0,24,1),WascoMERRAdiurnal['100m wind speed']-WascoMERRAdiurnalStd['100m wind speed'],WascoMERRAdiurnal['100m wind speed']+WascoMERRAdiurnalStd['100m wind speed'],alpha=0.1,color='green')
plt.fill_between(np.arange(0,24,1),WascoLidardiurnal-WascoLidardiurnalStd,WascoLidardiurnal+WascoLidardiurnalStd,alpha=0.1,color='black')

plt.xlabel('Hour of day (UTC)', fontsize=12)
plt.ylabel('Mean wind speed (m/s)')
plt.legend()
plt.xticks(np.arange(0,24,1))
# plt.savefig('WascoDiurnalTotal')
plt.show()

# %%
# Wasco Diurnal Cycle DJF

plt.plot(WascoERADJFdiurnal, label='ERA-5',color='orange')
plt.plot(WascoWRFDJFdiurnal,label='WTK-WRF',color='blue')
plt.plot(WascoMERRADJFdiurnal,label='MERRA-2',color='green')
plt.plot(WascoLidarDJFdiurnal,'--',label='Lidar',color='black')

plt.fill_between(np.arange(0,24,1),WascoERADJFdiurnal['wind speed']-WascoERADJFdiurnalStd['wind speed'],WascoERADJFdiurnal['wind speed']+WascoERADJFdiurnalStd['wind speed'],alpha=0.1,color='orange')
plt.fill_between(np.arange(0,24,1),WascoWRFDJFdiurnal.windspeed_100m-WascoWRFDJFdiurnalStd.windspeed_100m,WascoWRFDJFdiurnal.windspeed_100m+WascoWRFDJFdiurnalStd.windspeed_100m,alpha=0.1,color='blue')
plt.fill_between(np.arange(0,24,1),WascoMERRADJFdiurnal['100m wind speed']-WascoMERRADJFdiurnalStd['100m wind speed'],WascoMERRADJFdiurnal['100m wind speed']+WascoMERRADJFdiurnalStd['100m wind speed'],alpha=0.1,color='green')
plt.fill_between(np.arange(0,24,1),WascoLidarDJFdiurnal-WascoLidardiurnalDJFStd,WascoLidarDJFdiurnal+WascoLidardiurnalDJFStd,alpha=0.1,color='black')

plt.xlabel('Hour of day during winter (UTC)', fontsize=12)
plt.ylabel('Mean wind speed (m/s)')
plt.legend()
plt.xticks(np.arange(0,24,1))
# plt.savefig('WascoDiurnalDJF')
plt.show()

# %%
# Wasco Diurnal Cycle MAM

plt.plot(WascoERAMAMdiurnal, label='ERA-5',color='orange')
plt.plot(WascoWRFMAMdiurnal,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAMAMdiurnal,label='MERRA-2',color='green')
plt.plot(WascoLidarMAMdiurnal,'--',label='Lidar',color='black')

plt.fill_between(np.arange(0,24,1),WascoERAMAMdiurnal['wind speed']-WascoERAMAMdiurnalStd['wind speed'],WascoERAMAMdiurnal['wind speed']+WascoERAMAMdiurnalStd['wind speed'],alpha=0.1,color='orange')
plt.fill_between(np.arange(0,24,1),WascoWRFMAMdiurnal.windspeed_100m-WascoWRFMAMdiurnalStd.windspeed_100m,WascoWRFMAMdiurnal.windspeed_100m+WascoWRFMAMdiurnalStd.windspeed_100m,alpha=0.1,color='blue')
plt.fill_between(np.arange(0,24,1),WascoMERRAMAMdiurnal['100m wind speed']-WascoMERRAMAMdiurnalStd['100m wind speed'],WascoMERRAMAMdiurnal['100m wind speed']+WascoMERRAMAMdiurnalStd['100m wind speed'],alpha=0.1,color='green')
plt.fill_between(np.arange(0,24,1),WascoLidarMAMdiurnal-WascoLidardiurnalMAMStd,WascoLidarMAMdiurnal+WascoLidardiurnalMAMStd,alpha=0.1,color='black')

plt.xlabel('Hour of day during spring (UTC)', fontsize=12)
plt.ylabel('Mean wind speed (m/s)')
plt.legend()
plt.xticks(np.arange(0,24,1))
# plt.savefig('WascoDiurnalMAM')
plt.show()

# %%
# Wasco Diurnal Cycle JJA

plt.plot(WascoERAJJAdiurnal, label='ERA-5',color='orange')
plt.plot(WascoWRFJJAdiurnal,label='WTK-WRF',color='blue')
plt.plot(WascoMERRAJJAdiurnal,label='MERRA-2',color='green')
plt.plot(WascoLidarJJAdiurnal,'--',label='Lidar',color='black')

plt.fill_between(np.arange(0,24,1),WascoERAJJAdiurnal['wind speed']-WascoERAJJAdiurnalStd['wind speed'],WascoERAJJAdiurnal['wind speed']+WascoERAJJAdiurnalStd['wind speed'],alpha=0.1,color='orange')
plt.fill_between(np.arange(0,24,1),WascoWRFJJAdiurnal.windspeed_100m-WascoWRFJJAdiurnalStd.windspeed_100m,WascoWRFJJAdiurnal.windspeed_100m+WascoWRFJJAdiurnalStd.windspeed_100m,alpha=0.1,color='blue')
plt.fill_between(np.arange(0,24,1),WascoMERRAJJAdiurnal['100m wind speed']-WascoMERRAJJAdiurnalStd['100m wind speed'],WascoMERRAJJAdiurnal['100m wind speed']+WascoMERRAJJAdiurnalStd['100m wind speed'],alpha=0.1,color='green')
plt.fill_between(np.arange(0,24,1),WascoLidarJJAdiurnal-WascoLidardiurnalJJAStd,WascoLidarJJAdiurnal+WascoLidardiurnalJJAStd,alpha=0.1,color='black')

plt.xlabel('Hour of day during summer (UTC)', fontsize=12)
plt.ylabel('Mean wind speed (m/s)')
plt.legend()
plt.xticks(np.arange(0,24,1))
# plt.savefig('WascoDiurnalJJA')
plt.show()

# %%
# Wasco Diurnal Cycle SON

plt.plot(WascoERASONdiurnal, label='ERA-5',color='orange')
plt.plot(WascoWRFSONdiurnal,label='WTK-WRF',color='blue')
plt.plot(WascoMERRASONdiurnal,label='MERRA-2',color='green')
plt.plot(WascoLidarSONdiurnal,'--',label='Lidar',color='black')

plt.fill_between(np.arange(0,24,1),WascoERASONdiurnal['wind speed']-WascoERASONdiurnalStd['wind speed'],WascoERASONdiurnal['wind speed']+WascoERASONdiurnalStd['wind speed'],alpha=0.1,color='orange')
plt.fill_between(np.arange(0,24,1),WascoWRFSONdiurnal.windspeed_100m-WascoWRFSONdiurnalStd.windspeed_100m,WascoWRFSONdiurnal.windspeed_100m+WascoWRFSONdiurnalStd.windspeed_100m,alpha=0.1,color='blue')
plt.fill_between(np.arange(0,24,1),WascoMERRASONdiurnal['100m wind speed']-WascoMERRASONdiurnalStd['100m wind speed'],WascoMERRASONdiurnal['100m wind speed']+WascoMERRASONdiurnalStd['100m wind speed'],alpha=0.1,color='green')
plt.fill_between(np.arange(0,24,1),WascoLidarSONdiurnal-WascoLidardiurnalSONStd,WascoLidarSONdiurnal+WascoLidardiurnalSONStd,alpha=0.1,color='black')

plt.xlabel('Hour of day during fall (UTC)', fontsize=12)
plt.ylabel('Mean wind speed (m/s)')
plt.legend()
plt.xticks(np.arange(0,24,1))
# plt.savefig('WascoDiurnalSON')
plt.show()

# %%
# ERA interpolation to match heights of other models + observations

# interpolation of 54 and 79 meter heights (66.5) used for comparison to 60 meters
WascoERAIntp67=(WascoERAWS[::,8]+WascoERAWS[::,7])/2

# interpolation of 106 and 137 meter heights (121.5) used for comparison to 120 meters
WascoERAIntp122=(WascoERAWS[::,6]+WascoERAWS[::,5])/2

# %%
# compilation of all comparison methods, heights into one matching dataframe with consistent time series

WascoWS=pd.DataFrame()
WascoWS['Time']=WascoMERRAdf.index

WascoWS['MERRA60']=WascoMERRAWS[::,1]
WascoWS['MERRA80']=WascoMERRAWS[::,2]
WascoWS['MERRA100']=WascoMERRAWS[::,3]
WascoWS['MERRA120']=WascoMERRAWS[::,4]
WascoWS['MERRA140']=WascoMERRAWS[::,5]

WascoWS['Lidar60']=WascoLidarWS[::,1]
WascoWS['Lidar80']=WascoLidarWS[::,2]
WascoWS['Lidar100']=WascoLidarWS[::,3]
WascoWS['Lidar120']=WascoLidarWS[::,4]
WascoWS['Lidar140']=WascoLidarWS[::,5]

WascoWS['WRF60']=WascoWRFWS[::,0]
WascoWS['WRF80']=WascoWRFWS[::,1]
WascoWS['WRF100']=WascoWRFWS[::,2]
WascoWS['WRF120']=WascoWRFWS[::,3]
WascoWS['WRF140']=WascoWRFWS[::,4]

WascoWS['ERA66.5']=WascoERAIntp67
WascoWS['ERA79']=WascoERAWS[::,7]
WascoWS['ERA106']=WascoERAWS[::,6]
WascoWS['ERA121.5']=WascoERAIntp122
WascoWS['ERA140']=WascoERAWS[::,5]

WascoZComp=[60,80,100,120,140]
# WascoWS

WascoWSnan=WascoWS.dropna()

WascoWSnanDJF=WascoWSnan[(WascoWSnan.Time.str.contains('-12-'))|(WascoWSnan.Time.str.contains('-01-'))|(WascoWSnan.Time.str.contains('-02-'))]
WascoWSnanMAM=WascoWSnan[(WascoWSnan.Time.str.contains('-03-'))|(WascoWSnan.Time.str.contains('-04-'))|(WascoWSnan.Time.str.contains('-05-'))]
WascoWSnanJJA=WascoWSnan[(WascoWSnan.Time.str.contains('-06-'))|(WascoWSnan.Time.str.contains('-07-'))|(WascoWSnan.Time.str.contains('-08-'))]
WascoWSnanSON=WascoWSnan[(WascoWSnan.Time.str.contains('-09-'))|(WascoWSnan.Time.str.contains('-10-'))|(WascoWSnan.Time.str.contains('-11-'))]

# %%
# Wasco Bias Total

WascoBiasERA=np.zeros((8784,5))

WascoBiasERA[::,0]=(WascoWS['ERA66.5'])-(WascoWS['Lidar60'])
WascoBiasERA[::,1]=(WascoWS['ERA79'])-(WascoWS['Lidar80'])
WascoBiasERA[::,2]=(WascoWS['ERA106'])-(WascoWS['Lidar100'])
WascoBiasERA[::,3]=(WascoWS['ERA121.5'])-(WascoWS['Lidar120'])
WascoBiasERA[::,4]=(WascoWS['ERA140'])-(WascoWS['Lidar140'])
WascoBiasMERRA=np.zeros((8784,5))

WascoBiasMERRA[::,0]=(WascoWS['MERRA60'])-(WascoWS['Lidar60'])
WascoBiasMERRA[::,1]=(WascoWS['MERRA80'])-(WascoWS['Lidar80'])
WascoBiasMERRA[::,2]=(WascoWS['MERRA100'])-(WascoWS['Lidar100'])
WascoBiasMERRA[::,3]=(WascoWS['MERRA120'])-(WascoWS['Lidar120'])
WascoBiasMERRA[::,4]=(WascoWS['MERRA140'])-(WascoWS['Lidar140'])

WascoBiasWRF=np.zeros((8784,5))

WascoBiasWRF[::,0]=(WascoWS['WRF60'])-(WascoWS['Lidar60'])
WascoBiasWRF[::,1]=(WascoWS['WRF80'])-(WascoWS['Lidar80'])
WascoBiasWRF[::,2]=(WascoWS['WRF100'])-(WascoWS['Lidar100'])
WascoBiasWRF[::,3]=(WascoWS['WRF120'])-(WascoWS['Lidar120'])
WascoBiasWRF[::,4]=(WascoWS['WRF140'])-(WascoWS['Lidar140'])

# %%
# Wasco Bias Total
fig,ax=plt.subplots()
ax.plot(np.nanmean(WascoBiasWRF,axis=0),WascoZComp, label = 'WTK-WRF',color='blue')
ax.plot(np.nanmean(WascoBiasMERRA,axis=0),WascoZComp,label='MERRA-2',color='green')
ax.plot(np.nanmean(WascoBiasERA,axis=0),WascoZComp,label='ERA-5',color='orange')


ax.axvline(x = 0, linestyle = 'dotted', alpha = 0.5, c = 'k')
ax.legend(fontsize = 12)
ax.set_xlabel('Mean bias (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([-5,5])
# plt.savefig('WascoBiasTotal')
plt.show()

# %%
# Wasco Bias DJF


WascoBiasDJFERA=np.zeros((1200,5))

WascoBiasDJFERA[::,0]=(WascoWSnanDJF['ERA66.5'])-(WascoWSnanDJF['Lidar60'])
WascoBiasDJFERA[::,1]=(WascoWSnanDJF['ERA79'])-(WascoWSnanDJF['Lidar80'])
WascoBiasDJFERA[::,2]=(WascoWSnanDJF['ERA106'])-(WascoWSnanDJF['Lidar100'])
WascoBiasDJFERA[::,3]=(WascoWSnanDJF['ERA121.5'])-(WascoWSnanDJF['Lidar120'])
WascoBiasDJFERA[::,4]=(WascoWSnanDJF['ERA140'])-(WascoWSnanDJF['Lidar140'])

WascoBiasDJFMERRA=np.zeros((1200,5))

WascoBiasDJFMERRA[::,0]=(WascoWSnanDJF['MERRA60'])-(WascoWSnanDJF['Lidar60'])
WascoBiasDJFMERRA[::,1]=(WascoWSnanDJF['MERRA80'])-(WascoWSnanDJF['Lidar80'])
WascoBiasDJFMERRA[::,2]=(WascoWSnanDJF['MERRA100'])-(WascoWSnanDJF['Lidar100'])
WascoBiasDJFMERRA[::,3]=(WascoWSnanDJF['MERRA120'])-(WascoWSnanDJF['Lidar120'])
WascoBiasDJFMERRA[::,4]=(WascoWSnanDJF['MERRA140'])-(WascoWSnanDJF['Lidar140'])

WascoBiasDJFWRF=np.zeros((1200,5))

WascoBiasDJFWRF[::,0]=(WascoWSnanDJF['WRF60'])-(WascoWSnanDJF['Lidar60'])
WascoBiasDJFWRF[::,1]=(WascoWSnanDJF['WRF80'])-(WascoWSnanDJF['Lidar80'])
WascoBiasDJFWRF[::,2]=(WascoWSnanDJF['WRF100'])-(WascoWSnanDJF['Lidar100'])
WascoBiasDJFWRF[::,3]=(WascoWSnanDJF['WRF120'])-(WascoWSnanDJF['Lidar120'])
WascoBiasDJFWRF[::,4]=(WascoWSnanDJF['WRF140'])-(WascoWSnanDJF['Lidar140'])

# %%
# Wasco Bias DJF

fig,ax=plt.subplots()
ax.plot(np.nanmean(WascoBiasDJFWRF,axis=0),WascoZComp, label = 'WTK-WRF',color='blue')
ax.plot(np.nanmean(WascoBiasDJFMERRA,axis=0),WascoZComp,label='MERRA-2',color='green')
ax.plot(np.nanmean(WascoBiasDJFERA,axis=0),WascoZComp,label='ERA-5',color='orange')

ax.axvline(x = 0, linestyle = 'dotted', alpha = 0.5, c = 'k')
ax.legend(fontsize = 12)
ax.set_xlabel('Winter mean bias (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([-5,5])
# plt.savefig('WascoBiasDJF')
plt.show()

# %%
# Wasco Bias MAM


WascoBiasMAMERA=np.zeros((1551,5))

WascoBiasMAMERA[::,0]=(WascoWSnanMAM['ERA66.5'])-(WascoWSnanMAM['Lidar60'])
WascoBiasMAMERA[::,1]=(WascoWSnanMAM['ERA79'])-(WascoWSnanMAM['Lidar80'])
WascoBiasMAMERA[::,2]=(WascoWSnanMAM['ERA106'])-(WascoWSnanMAM['Lidar100'])
WascoBiasMAMERA[::,3]=(WascoWSnanMAM['ERA121.5'])-(WascoWSnanMAM['Lidar120'])
WascoBiasMAMERA[::,4]=(WascoWSnanMAM['ERA140'])-(WascoWSnanMAM['Lidar140'])

WascoBiasMAMMERRA=np.zeros((1551,5))

WascoBiasMAMMERRA[::,0]=(WascoWSnanMAM['MERRA60'])-(WascoWSnanMAM['Lidar60'])
WascoBiasMAMMERRA[::,1]=(WascoWSnanMAM['MERRA80'])-(WascoWSnanMAM['Lidar80'])
WascoBiasMAMMERRA[::,2]=(WascoWSnanMAM['MERRA100'])-(WascoWSnanMAM['Lidar100'])
WascoBiasMAMMERRA[::,3]=(WascoWSnanMAM['MERRA120'])-(WascoWSnanMAM['Lidar120'])
WascoBiasMAMMERRA[::,4]=(WascoWSnanMAM['MERRA140'])-(WascoWSnanMAM['Lidar140'])

WascoBiasMAMWRF=np.zeros((1551,5))

WascoBiasMAMWRF[::,0]=(WascoWSnanMAM['WRF60'])-(WascoWSnanMAM['Lidar60'])
WascoBiasMAMWRF[::,1]=(WascoWSnanMAM['WRF80'])-(WascoWSnanMAM['Lidar80'])
WascoBiasMAMWRF[::,2]=(WascoWSnanMAM['WRF100'])-(WascoWSnanMAM['Lidar100'])
WascoBiasMAMWRF[::,3]=(WascoWSnanMAM['WRF120'])-(WascoWSnanMAM['Lidar120'])
WascoBiasMAMWRF[::,4]=(WascoWSnanMAM['WRF140'])-(WascoWSnanMAM['Lidar140'])

# %%
# Wasco Bias MAM

fig,ax=plt.subplots()
ax.plot(np.nanmean(WascoBiasMAMWRF,axis=0),WascoZComp, label = 'WTK-WRF',color='blue')
ax.plot(np.nanmean(WascoBiasMAMMERRA,axis=0),WascoZComp,label='MERRA-2',color='green')
ax.plot(np.nanmean(WascoBiasMAMERA,axis=0),WascoZComp,label='ERA-5',color='orange')

ax.axvline(x = 0, linestyle = 'dotted', alpha = 0.5, c = 'k')
ax.legend(fontsize = 12)
ax.set_xlabel('Spring mean bias (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([-5,5])
# plt.savefig('WascoBiasMAM')
plt.show()

# %%
# Wasco Bias JJA


WascoBiasJJAERA=np.zeros((1884,5))

WascoBiasJJAERA[::,0]=(WascoWSnanJJA['ERA66.5'])-(WascoWSnanJJA['Lidar60'])
WascoBiasJJAERA[::,1]=(WascoWSnanJJA['ERA79'])-(WascoWSnanJJA['Lidar80'])
WascoBiasJJAERA[::,2]=(WascoWSnanJJA['ERA106'])-(WascoWSnanJJA['Lidar100'])
WascoBiasJJAERA[::,3]=(WascoWSnanJJA['ERA121.5'])-(WascoWSnanJJA['Lidar120'])
WascoBiasJJAERA[::,4]=(WascoWSnanJJA['ERA140'])-(WascoWSnanJJA['Lidar140'])

WascoBiasJJAMERRA=np.zeros((1884,5))

WascoBiasJJAMERRA[::,0]=(WascoWSnanJJA['MERRA60'])-(WascoWSnanJJA['Lidar60'])
WascoBiasJJAMERRA[::,1]=(WascoWSnanJJA['MERRA80'])-(WascoWSnanJJA['Lidar80'])
WascoBiasJJAMERRA[::,2]=(WascoWSnanJJA['MERRA100'])-(WascoWSnanJJA['Lidar100'])
WascoBiasJJAMERRA[::,3]=(WascoWSnanJJA['MERRA120'])-(WascoWSnanJJA['Lidar120'])
WascoBiasJJAMERRA[::,4]=(WascoWSnanJJA['MERRA140'])-(WascoWSnanJJA['Lidar140'])

WascoBiasJJAWRF=np.zeros((1884,5))

WascoBiasJJAWRF[::,0]=(WascoWSnanJJA['WRF60'])-(WascoWSnanJJA['Lidar60'])
WascoBiasJJAWRF[::,1]=(WascoWSnanJJA['WRF80'])-(WascoWSnanJJA['Lidar80'])
WascoBiasJJAWRF[::,2]=(WascoWSnanJJA['WRF100'])-(WascoWSnanJJA['Lidar100'])
WascoBiasJJAWRF[::,3]=(WascoWSnanJJA['WRF120'])-(WascoWSnanJJA['Lidar120'])
WascoBiasJJAWRF[::,4]=(WascoWSnanJJA['WRF140'])-(WascoWSnanJJA['Lidar140'])

# %%
# Wasco Bias JJA

fig,ax=plt.subplots()
ax.plot(np.nanmean(WascoBiasJJAWRF,axis=0),WascoZComp, label = 'WTK-WRF',color='blue')
ax.plot(np.nanmean(WascoBiasJJAMERRA,axis=0),WascoZComp,label='MERRA-2',color='green')
ax.plot(np.nanmean(WascoBiasJJAERA,axis=0),WascoZComp,label='ERA-5',color='orange')

ax.axvline(x = 0, linestyle = 'dotted', alpha = 0.5, c = 'k')
ax.legend(fontsize = 12)
ax.set_xlabel('Summer mean bias (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([-5,5])
# plt.savefig('WascoBiasJJA')
plt.show()

# %%
# Wasco Bias SON


WascoBiasSONERA=np.zeros((1778,5))

WascoBiasSONERA[::,0]=(WascoWSnanSON['ERA66.5'])-(WascoWSnanSON['Lidar60'])
WascoBiasSONERA[::,1]=(WascoWSnanSON['ERA79'])-(WascoWSnanSON['Lidar80'])
WascoBiasSONERA[::,2]=(WascoWSnanSON['ERA106'])-(WascoWSnanSON['Lidar100'])
WascoBiasSONERA[::,3]=(WascoWSnanSON['ERA121.5'])-(WascoWSnanSON['Lidar120'])
WascoBiasSONERA[::,4]=(WascoWSnanSON['ERA140'])-(WascoWSnanSON['Lidar140'])

WascoBiasSONMERRA=np.zeros((1778,5))

WascoBiasSONMERRA[::,0]=(WascoWSnanSON['MERRA60'])-(WascoWSnanSON['Lidar60'])
WascoBiasSONMERRA[::,1]=(WascoWSnanSON['MERRA80'])-(WascoWSnanSON['Lidar80'])
WascoBiasSONMERRA[::,2]=(WascoWSnanSON['MERRA100'])-(WascoWSnanSON['Lidar100'])
WascoBiasSONMERRA[::,3]=(WascoWSnanSON['MERRA120'])-(WascoWSnanSON['Lidar120'])
WascoBiasSONMERRA[::,4]=(WascoWSnanSON['MERRA140'])-(WascoWSnanSON['Lidar140'])

WascoBiasSONWRF=np.zeros((1778,5))

WascoBiasSONWRF[::,0]=(WascoWSnanSON['WRF60'])-(WascoWSnanSON['Lidar60'])
WascoBiasSONWRF[::,1]=(WascoWSnanSON['WRF80'])-(WascoWSnanSON['Lidar80'])
WascoBiasSONWRF[::,2]=(WascoWSnanSON['WRF100'])-(WascoWSnanSON['Lidar100'])
WascoBiasSONWRF[::,3]=(WascoWSnanSON['WRF120'])-(WascoWSnanSON['Lidar120'])
WascoBiasSONWRF[::,4]=(WascoWSnanSON['WRF140'])-(WascoWSnanSON['Lidar140'])

# %%
# Wasco Bias SON

fig,ax=plt.subplots()
ax.plot(np.nanmean(WascoBiasSONWRF,axis=0),WascoZComp, label = 'WTK-WRF',color='blue')
ax.plot(np.nanmean(WascoBiasSONMERRA,axis=0),WascoZComp,label='MERRA-2',color='green')
ax.plot(np.nanmean(WascoBiasSONERA,axis=0),WascoZComp,label='ERA-5',color='orange')

ax.axvline(x = 0, linestyle = 'dotted', alpha = 0.5, c = 'k')
ax.legend(fontsize = 12)
ax.set_xlabel('Fall mean bias (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([-5,5])
# plt.savefig('WascoBiasSON')
plt.show()

# %%
# Wasco CC Total

WascoR2ERA=np.zeros(5)
WascoR2ERA[0]=np.power((np.corrcoef(WascoWSnan['Lidar60'],WascoWSnan['ERA66.5'])[0,1]),2)
WascoR2ERA[1]=np.power((np.corrcoef(WascoWSnan['Lidar80'],WascoWSnan['ERA79'])[0,1]),2)
WascoR2ERA[2]=np.power((np.corrcoef(WascoWSnan['Lidar100'],WascoWSnan['ERA106'])[0,1]),2)
WascoR2ERA[3]=np.power((np.corrcoef(WascoWSnan['Lidar120'],WascoWSnan['ERA121.5'])[0,1]),2)
WascoR2ERA[4]=np.power((np.corrcoef(WascoWSnan['Lidar140'],WascoWSnan['ERA140'])[0,1]),2)

WascoR2MERRA=np.zeros(5)
WascoR2MERRA[0]=np.power((np.corrcoef(WascoWSnan['Lidar60'],WascoWSnan['MERRA60'])[0,1]),2)
WascoR2MERRA[1]=np.power((np.corrcoef(WascoWSnan['Lidar80'],WascoWSnan['MERRA80'])[0,1]),2)
WascoR2MERRA[2]=np.power((np.corrcoef(WascoWSnan['Lidar100'],WascoWSnan['MERRA100'])[0,1]),2)
WascoR2MERRA[3]=np.power((np.corrcoef(WascoWSnan['Lidar120'],WascoWSnan['MERRA120'])[0,1]),2)
WascoR2MERRA[4]=np.power((np.corrcoef(WascoWSnan['Lidar140'],WascoWSnan['MERRA140'])[0,1]),2)

WascoR2WRF=np.zeros(5)
WascoR2WRF[0]=np.power((np.corrcoef(WascoWSnan['Lidar60'],WascoWSnan['WRF60'])[0,1]),2)
WascoR2WRF[1]=np.power((np.corrcoef(WascoWSnan['Lidar80'],WascoWSnan['WRF80'])[0,1]),2)
WascoR2WRF[2]=np.power((np.corrcoef(WascoWSnan['Lidar100'],WascoWSnan['WRF100'])[0,1]),2)
WascoR2WRF[3]=np.power((np.corrcoef(WascoWSnan['Lidar120'],WascoWSnan['WRF120'])[0,1]),2)
WascoR2WRF[4]=np.power((np.corrcoef(WascoWSnan['Lidar140'],WascoWSnan['WRF140'])[0,1]),2)

# %%
# Wasco CC Total

fig,ax=plt.subplots()
ax.plot(WascoR2ERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoR2MERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoR2WRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Correlation Coefficient ($R^2$)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,1])
# plt.savefig('WascoR2Total')
plt.show()

# %%
# Wasco CC DJF

WascoR2DJFERA=np.zeros(5)
WascoR2DJFERA[0]=np.power((np.corrcoef(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['ERA66.5'])[0,1]),2)
WascoR2DJFERA[1]=np.power((np.corrcoef(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['ERA79'])[0,1]),2)
WascoR2DJFERA[2]=np.power((np.corrcoef(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['ERA106'])[0,1]),2)
WascoR2DJFERA[3]=np.power((np.corrcoef(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['ERA121.5'])[0,1]),2)
WascoR2DJFERA[4]=np.power((np.corrcoef(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['ERA140'])[0,1]),2)

WascoR2DJFMERRA=np.zeros(5)
WascoR2DJFMERRA[0]=np.power((np.corrcoef(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['MERRA60'])[0,1]),2)
WascoR2DJFMERRA[1]=np.power((np.corrcoef(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['MERRA80'])[0,1]),2)
WascoR2DJFMERRA[2]=np.power((np.corrcoef(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['MERRA100'])[0,1]),2)
WascoR2DJFMERRA[3]=np.power((np.corrcoef(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['MERRA120'])[0,1]),2)
WascoR2DJFMERRA[4]=np.power((np.corrcoef(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['MERRA140'])[0,1]),2)

WascoR2DJFWRF=np.zeros(5)
WascoR2DJFWRF[0]=np.power((np.corrcoef(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['WRF60'])[0,1]),2)
WascoR2DJFWRF[1]=np.power((np.corrcoef(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['WRF80'])[0,1]),2)
WascoR2DJFWRF[2]=np.power((np.corrcoef(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['WRF100'])[0,1]),2)
WascoR2DJFWRF[3]=np.power((np.corrcoef(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['WRF120'])[0,1]),2)
WascoR2DJFWRF[4]=np.power((np.corrcoef(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['WRF140'])[0,1]),2)

# %%
# Wasco CC DJF

fig,ax=plt.subplots()

ax.plot(WascoR2DJFERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoR2DJFMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoR2DJFWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Winter Correlation Coefficient ($R^2$)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,1])
# plt.savefig('WascoR2DJF')
plt.show()

# %%
# Wasco CC MAM

WascoR2MAMERA=np.zeros(5)
WascoR2MAMERA[0]=np.power((np.corrcoef(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['ERA66.5'])[0,1]),2)
WascoR2MAMERA[1]=np.power((np.corrcoef(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['ERA79'])[0,1]),2)
WascoR2MAMERA[2]=np.power((np.corrcoef(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['ERA106'])[0,1]),2)
WascoR2MAMERA[3]=np.power((np.corrcoef(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['ERA121.5'])[0,1]),2)
WascoR2MAMERA[4]=np.power((np.corrcoef(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['ERA140'])[0,1]),2)

WascoR2MAMMERRA=np.zeros(5)
WascoR2MAMMERRA[0]=np.power((np.corrcoef(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['MERRA60'])[0,1]),2)
WascoR2MAMMERRA[1]=np.power((np.corrcoef(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['MERRA80'])[0,1]),2)
WascoR2MAMMERRA[2]=np.power((np.corrcoef(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['MERRA100'])[0,1]),2)
WascoR2MAMMERRA[3]=np.power((np.corrcoef(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['MERRA120'])[0,1]),2)
WascoR2MAMMERRA[4]=np.power((np.corrcoef(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['MERRA140'])[0,1]),2)

WascoR2MAMWRF=np.zeros(5)
WascoR2MAMWRF[0]=np.power((np.corrcoef(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['WRF60'])[0,1]),2)
WascoR2MAMWRF[1]=np.power((np.corrcoef(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['WRF80'])[0,1]),2)
WascoR2MAMWRF[2]=np.power((np.corrcoef(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['WRF100'])[0,1]),2)
WascoR2MAMWRF[3]=np.power((np.corrcoef(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['WRF120'])[0,1]),2)
WascoR2MAMWRF[4]=np.power((np.corrcoef(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['WRF140'])[0,1]),2)

# %%
# Wasco CC MAM

fig,ax=plt.subplots()

ax.plot(WascoR2MAMERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoR2MAMMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoR2MAMWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Spring Correlation Coefficient ($R^2$)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,1])
# plt.savefig('WascoR2MAM')
plt.show()

# %%
# Wasco CC JJA

WascoR2JJAERA=np.zeros(5)
WascoR2JJAERA[0]=np.power((np.corrcoef(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['ERA66.5'])[0,1]),2)
WascoR2JJAERA[1]=np.power((np.corrcoef(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['ERA79'])[0,1]),2)
WascoR2JJAERA[2]=np.power((np.corrcoef(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['ERA106'])[0,1]),2)
WascoR2JJAERA[3]=np.power((np.corrcoef(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['ERA121.5'])[0,1]),2)
WascoR2JJAERA[4]=np.power((np.corrcoef(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['ERA140'])[0,1]),2)

WascoR2JJAMERRA=np.zeros(5)
WascoR2JJAMERRA[0]=np.power((np.corrcoef(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['MERRA60'])[0,1]),2)
WascoR2JJAMERRA[1]=np.power((np.corrcoef(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['MERRA80'])[0,1]),2)
WascoR2JJAMERRA[2]=np.power((np.corrcoef(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['MERRA100'])[0,1]),2)
WascoR2JJAMERRA[3]=np.power((np.corrcoef(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['MERRA120'])[0,1]),2)
WascoR2JJAMERRA[4]=np.power((np.corrcoef(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['MERRA140'])[0,1]),2)

WascoR2JJAWRF=np.zeros(5)
WascoR2JJAWRF[0]=np.power((np.corrcoef(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['WRF60'])[0,1]),2)
WascoR2JJAWRF[1]=np.power((np.corrcoef(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['WRF80'])[0,1]),2)
WascoR2JJAWRF[2]=np.power((np.corrcoef(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['WRF100'])[0,1]),2)
WascoR2JJAWRF[3]=np.power((np.corrcoef(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['WRF120'])[0,1]),2)
WascoR2JJAWRF[4]=np.power((np.corrcoef(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['WRF140'])[0,1]),2)

# %%
# Wasco CC JJA

fig,ax=plt.subplots()

ax.plot(WascoR2JJAERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoR2JJAMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoR2JJAWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Summer Correlation Coefficient ($R^2$)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,1])
# plt.savefig('WascoR2JJA')
plt.show()

# %%
# Wasco CC SON

WascoR2SONERA=np.zeros(5)
WascoR2SONERA[0]=np.power((np.corrcoef(WascoWSnanSON['Lidar60'],WascoWSnanSON['ERA66.5'])[0,1]),2)
WascoR2SONERA[1]=np.power((np.corrcoef(WascoWSnanSON['Lidar80'],WascoWSnanSON['ERA79'])[0,1]),2)
WascoR2SONERA[2]=np.power((np.corrcoef(WascoWSnanSON['Lidar100'],WascoWSnanSON['ERA106'])[0,1]),2)
WascoR2SONERA[3]=np.power((np.corrcoef(WascoWSnanSON['Lidar120'],WascoWSnanSON['ERA121.5'])[0,1]),2)
WascoR2SONERA[4]=np.power((np.corrcoef(WascoWSnanSON['Lidar140'],WascoWSnanSON['ERA140'])[0,1]),2)

WascoR2SONMERRA=np.zeros(5)
WascoR2SONMERRA[0]=np.power((np.corrcoef(WascoWSnanSON['Lidar60'],WascoWSnanSON['MERRA60'])[0,1]),2)
WascoR2SONMERRA[1]=np.power((np.corrcoef(WascoWSnanSON['Lidar80'],WascoWSnanSON['MERRA80'])[0,1]),2)
WascoR2SONMERRA[2]=np.power((np.corrcoef(WascoWSnanSON['Lidar100'],WascoWSnanSON['MERRA100'])[0,1]),2)
WascoR2SONMERRA[3]=np.power((np.corrcoef(WascoWSnanSON['Lidar120'],WascoWSnanSON['MERRA120'])[0,1]),2)
WascoR2SONMERRA[4]=np.power((np.corrcoef(WascoWSnanSON['Lidar140'],WascoWSnanSON['MERRA140'])[0,1]),2)

WascoR2SONWRF=np.zeros(5)
WascoR2SONWRF[0]=np.power((np.corrcoef(WascoWSnanSON['Lidar60'],WascoWSnanSON['WRF60'])[0,1]),2)
WascoR2SONWRF[1]=np.power((np.corrcoef(WascoWSnanSON['Lidar80'],WascoWSnanSON['WRF80'])[0,1]),2)
WascoR2SONWRF[2]=np.power((np.corrcoef(WascoWSnanSON['Lidar100'],WascoWSnanSON['WRF100'])[0,1]),2)
WascoR2SONWRF[3]=np.power((np.corrcoef(WascoWSnanSON['Lidar120'],WascoWSnanSON['WRF120'])[0,1]),2)
WascoR2SONWRF[4]=np.power((np.corrcoef(WascoWSnanSON['Lidar140'],WascoWSnanSON['WRF140'])[0,1]),2)

# %%
# Wasco CC SON

fig,ax=plt.subplots()

ax.plot(WascoR2SONERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoR2SONMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoR2SONWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Fall Correlation Coefficient ($R^2$)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,1])
# plt.savefig('WascoR2SON')
plt.show()

# %%
# Wasco cRMSE Total

WascoCRMSEERA=np.zeros(5)
WascoCRMSEERA[0]=(sm.centered_rms_dev(WascoWSnan['Lidar60'],WascoWSnan['ERA66.5']))
WascoCRMSEERA[1]=(sm.centered_rms_dev(WascoWSnan['Lidar80'],WascoWSnan['ERA79']))
WascoCRMSEERA[2]=(sm.centered_rms_dev(WascoWSnan['Lidar100'],WascoWSnan['ERA106']))
WascoCRMSEERA[3]=(sm.centered_rms_dev(WascoWSnan['Lidar120'],WascoWSnan['ERA121.5']))
WascoCRMSEERA[4]=(sm.centered_rms_dev(WascoWSnan['Lidar140'],WascoWSnan['ERA140']))

WascoCRMSEMERRA=np.zeros(5)
WascoCRMSEMERRA[0]=(sm.centered_rms_dev(WascoWSnan['Lidar60'],WascoWSnan['MERRA60']))
WascoCRMSEMERRA[1]=(sm.centered_rms_dev(WascoWSnan['Lidar80'],WascoWSnan['MERRA80']))
WascoCRMSEMERRA[2]=(sm.centered_rms_dev(WascoWSnan['Lidar100'],WascoWSnan['MERRA100']))
WascoCRMSEMERRA[3]=(sm.centered_rms_dev(WascoWSnan['Lidar120'],WascoWSnan['MERRA120']))
WascoCRMSEMERRA[4]=(sm.centered_rms_dev(WascoWSnan['Lidar140'],WascoWSnan['MERRA140']))

WascoCRMSEWRF=np.zeros(5)
WascoCRMSEWRF[0]=(sm.centered_rms_dev(WascoWSnan['Lidar60'],WascoWSnan['WRF60']))
WascoCRMSEWRF[1]=(sm.centered_rms_dev(WascoWSnan['Lidar80'],WascoWSnan['WRF80']))
WascoCRMSEWRF[2]=(sm.centered_rms_dev(WascoWSnan['Lidar100'],WascoWSnan['WRF100']))
WascoCRMSEWRF[3]=(sm.centered_rms_dev(WascoWSnan['Lidar120'],WascoWSnan['WRF120']))
WascoCRMSEWRF[4]=(sm.centered_rms_dev(WascoWSnan['Lidar140'],WascoWSnan['WRF140']))

# %%
# Wasco cRMSE Total

fig,ax=plt.subplots()
ax.plot(WascoCRMSEERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoCRMSEMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoCRMSEWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('cRMSE (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoCRMSETotal')
plt.show()

# %%
# Wasco cRMSE DJF

WascoCRMSEDJFERA=np.zeros(5)
WascoCRMSEDJFERA[0]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['ERA66.5']))
WascoCRMSEDJFERA[1]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['ERA79']))
WascoCRMSEDJFERA[2]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['ERA106']))
WascoCRMSEDJFERA[3]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['ERA121.5']))
WascoCRMSEDJFERA[4]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['ERA140']))

WascoCRMSEDJFMERRA=np.zeros(5)
WascoCRMSEDJFMERRA[0]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['MERRA60']))
WascoCRMSEDJFMERRA[1]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['MERRA80']))
WascoCRMSEDJFMERRA[2]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['MERRA100']))
WascoCRMSEDJFMERRA[3]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['MERRA120']))
WascoCRMSEDJFMERRA[4]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['MERRA140']))

WascoCRMSEDJFWRF=np.zeros(5)
WascoCRMSEDJFWRF[0]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['WRF60']))
WascoCRMSEDJFWRF[1]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['WRF80']))
WascoCRMSEDJFWRF[2]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['WRF100']))
WascoCRMSEDJFWRF[3]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['WRF120']))
WascoCRMSEDJFWRF[4]=(sm.centered_rms_dev(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['WRF140']))

# %%
# Wasco cRMSE DJF

fig,ax=plt.subplots()
ax.plot(WascoCRMSEDJFERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoCRMSEDJFMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoCRMSEDJFWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Winter cRMSE (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoCRMSEDJF')
plt.show()

# %%
# Wasco cRMSE MAM

WascoCRMSEMAMERA=np.zeros(5)
WascoCRMSEMAMERA[0]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['ERA66.5']))
WascoCRMSEMAMERA[1]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['ERA79']))
WascoCRMSEMAMERA[2]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['ERA106']))
WascoCRMSEMAMERA[3]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['ERA121.5']))
WascoCRMSEMAMERA[4]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['ERA140']))

WascoCRMSEMAMMERRA=np.zeros(5)
WascoCRMSEMAMMERRA[0]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['MERRA60']))
WascoCRMSEMAMMERRA[1]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['MERRA80']))
WascoCRMSEMAMMERRA[2]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['MERRA100']))
WascoCRMSEMAMMERRA[3]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['MERRA120']))
WascoCRMSEMAMMERRA[4]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['MERRA140']))

WascoCRMSEMAMWRF=np.zeros(5)
WascoCRMSEMAMWRF[0]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['WRF60']))
WascoCRMSEMAMWRF[1]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['WRF80']))
WascoCRMSEMAMWRF[2]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['WRF100']))
WascoCRMSEMAMWRF[3]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['WRF120']))
WascoCRMSEMAMWRF[4]=(sm.centered_rms_dev(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['WRF140']))

# %%
# Wasco cRMSE MAM

fig,ax=plt.subplots()
ax.plot(WascoCRMSEMAMERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoCRMSEMAMMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoCRMSEMAMWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Spring cRMSE (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoCRMSEMAM')
plt.show()

# %%
# Wasco cRMSE JJA

WascoCRMSEJJAERA=np.zeros(5)
WascoCRMSEJJAERA[0]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['ERA66.5']))
WascoCRMSEJJAERA[1]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['ERA79']))
WascoCRMSEJJAERA[2]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['ERA106']))
WascoCRMSEJJAERA[3]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['ERA121.5']))
WascoCRMSEJJAERA[4]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['ERA140']))

WascoCRMSEJJAMERRA=np.zeros(5)
WascoCRMSEJJAMERRA[0]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['MERRA60']))
WascoCRMSEJJAMERRA[1]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['MERRA80']))
WascoCRMSEJJAMERRA[2]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['MERRA100']))
WascoCRMSEJJAMERRA[3]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['MERRA120']))
WascoCRMSEJJAMERRA[4]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['MERRA140']))

WascoCRMSEJJAWRF=np.zeros(5)
WascoCRMSEJJAWRF[0]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['WRF60']))
WascoCRMSEJJAWRF[1]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['WRF80']))
WascoCRMSEJJAWRF[2]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['WRF100']))
WascoCRMSEJJAWRF[3]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['WRF120']))
WascoCRMSEJJAWRF[4]=(sm.centered_rms_dev(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['WRF140']))

# %%
# Wasco cRMSE JJA

fig,ax=plt.subplots()
ax.plot(WascoCRMSEJJAERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoCRMSEJJAMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoCRMSEJJAWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Summer cRMSE (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoCRMSEJJA')
plt.show()

# %%
# Wasco cRMSE SON

WascoCRMSESONERA=np.zeros(5)
WascoCRMSESONERA[0]=(sm.centered_rms_dev(WascoWSnanSON['Lidar60'],WascoWSnanSON['ERA66.5']))
WascoCRMSESONERA[1]=(sm.centered_rms_dev(WascoWSnanSON['Lidar80'],WascoWSnanSON['ERA79']))
WascoCRMSESONERA[2]=(sm.centered_rms_dev(WascoWSnanSON['Lidar100'],WascoWSnanSON['ERA106']))
WascoCRMSESONERA[3]=(sm.centered_rms_dev(WascoWSnanSON['Lidar120'],WascoWSnanSON['ERA121.5']))
WascoCRMSESONERA[4]=(sm.centered_rms_dev(WascoWSnanSON['Lidar140'],WascoWSnanSON['ERA140']))

WascoCRMSESONMERRA=np.zeros(5)
WascoCRMSESONMERRA[0]=(sm.centered_rms_dev(WascoWSnanSON['Lidar60'],WascoWSnanSON['MERRA60']))
WascoCRMSESONMERRA[1]=(sm.centered_rms_dev(WascoWSnanSON['Lidar80'],WascoWSnanSON['MERRA80']))
WascoCRMSESONMERRA[2]=(sm.centered_rms_dev(WascoWSnanSON['Lidar100'],WascoWSnanSON['MERRA100']))
WascoCRMSESONMERRA[3]=(sm.centered_rms_dev(WascoWSnanSON['Lidar120'],WascoWSnanSON['MERRA120']))
WascoCRMSESONMERRA[4]=(sm.centered_rms_dev(WascoWSnanSON['Lidar140'],WascoWSnanSON['MERRA140']))

WascoCRMSESONWRF=np.zeros(5)
WascoCRMSESONWRF[0]=(sm.centered_rms_dev(WascoWSnanSON['Lidar60'],WascoWSnanSON['WRF60']))
WascoCRMSESONWRF[1]=(sm.centered_rms_dev(WascoWSnanSON['Lidar80'],WascoWSnanSON['WRF80']))
WascoCRMSESONWRF[2]=(sm.centered_rms_dev(WascoWSnanSON['Lidar100'],WascoWSnanSON['WRF100']))
WascoCRMSESONWRF[3]=(sm.centered_rms_dev(WascoWSnanSON['Lidar120'],WascoWSnanSON['WRF120']))
WascoCRMSESONWRF[4]=(sm.centered_rms_dev(WascoWSnanSON['Lidar140'],WascoWSnanSON['WRF140']))

# %%
# Wasco cRMSE SON

fig,ax=plt.subplots()
ax.plot(WascoCRMSESONERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoCRMSESONMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoCRMSESONWRF,WascoZComp,label='WTK-WRF',color='blue')

ax.legend(fontsize = 12)
ax.set_xlabel('Fall cRMSE (m/s)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoCRMSESON')
plt.show()

# %%
# Wasco EMD Total

WascoEMDERA=np.zeros(5)
WascoEMDERA[0]=(wasserstein_distance(WascoWSnan['Lidar60'],WascoWSnan['ERA66.5']))
WascoEMDERA[1]=(wasserstein_distance(WascoWSnan['Lidar80'],WascoWSnan['ERA79']))
WascoEMDERA[2]=(wasserstein_distance(WascoWSnan['Lidar100'],WascoWSnan['ERA106']))
WascoEMDERA[3]=(wasserstein_distance(WascoWSnan['Lidar120'],WascoWSnan['ERA121.5']))
WascoEMDERA[4]=(wasserstein_distance(WascoWSnan['Lidar140'],WascoWSnan['ERA140']))

WascoEMDMERRA=np.zeros(5)
WascoEMDMERRA[0]=(wasserstein_distance(WascoWSnan['Lidar60'],WascoWSnan['MERRA60']))
WascoEMDMERRA[1]=(wasserstein_distance(WascoWSnan['Lidar80'],WascoWSnan['MERRA80']))
WascoEMDMERRA[2]=(wasserstein_distance(WascoWSnan['Lidar100'],WascoWSnan['MERRA100']))
WascoEMDMERRA[3]=(wasserstein_distance(WascoWSnan['Lidar120'],WascoWSnan['MERRA120']))
WascoEMDMERRA[4]=(wasserstein_distance(WascoWSnan['Lidar140'],WascoWSnan['MERRA140']))

WascoEMDWRF=np.zeros(5)
WascoEMDWRF[0]=(wasserstein_distance(WascoWSnan['Lidar60'],WascoWSnan['WRF60']))
WascoEMDWRF[1]=(wasserstein_distance(WascoWSnan['Lidar80'],WascoWSnan['WRF80']))
WascoEMDWRF[2]=(wasserstein_distance(WascoWSnan['Lidar100'],WascoWSnan['WRF100']))
WascoEMDWRF[3]=(wasserstein_distance(WascoWSnan['Lidar120'],WascoWSnan['WRF120']))
WascoEMDWRF[4]=(wasserstein_distance(WascoWSnan['Lidar140'],WascoWSnan['WRF140']))

# %%
# Wasco EMD Total

fig,ax=plt.subplots()
ax.plot(WascoEMDERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoEMDMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoEMDWRF,WascoZComp,label='WRF',color='blue')
# 
# ax.legend(fontsize = 12)
ax.set_xlabel('EMD (m)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoEMDTotal')
# Out:
# (0, 5)

# %%
# Wasco EMD DJF

WascoEMDDJFERA=np.zeros(5)
WascoEMDDJFERA[0]=(wasserstein_distance(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['ERA66.5']))
WascoEMDDJFERA[1]=(wasserstein_distance(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['ERA79']))
WascoEMDDJFERA[2]=(wasserstein_distance(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['ERA106']))
WascoEMDDJFERA[3]=(wasserstein_distance(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['ERA121.5']))
WascoEMDDJFERA[4]=(wasserstein_distance(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['ERA140']))

WascoEMDDJFMERRA=np.zeros(5)
WascoEMDDJFMERRA[0]=(wasserstein_distance(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['MERRA60']))
WascoEMDDJFMERRA[1]=(wasserstein_distance(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['MERRA80']))
WascoEMDDJFMERRA[2]=(wasserstein_distance(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['MERRA100']))
WascoEMDDJFMERRA[3]=(wasserstein_distance(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['MERRA120']))
WascoEMDDJFMERRA[4]=(wasserstein_distance(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['MERRA140']))

WascoEMDDJFWRF=np.zeros(5)
WascoEMDDJFWRF[0]=(wasserstein_distance(WascoWSnanDJF['Lidar60'],WascoWSnanDJF['WRF60']))
WascoEMDDJFWRF[1]=(wasserstein_distance(WascoWSnanDJF['Lidar80'],WascoWSnanDJF['WRF80']))
WascoEMDDJFWRF[2]=(wasserstein_distance(WascoWSnanDJF['Lidar100'],WascoWSnanDJF['WRF100']))
WascoEMDDJFWRF[3]=(wasserstein_distance(WascoWSnanDJF['Lidar120'],WascoWSnanDJF['WRF120']))
WascoEMDDJFWRF[4]=(wasserstein_distance(WascoWSnanDJF['Lidar140'],WascoWSnanDJF['WRF140']))

# %%
# Wasco EMD DJF 

fig,ax=plt.subplots()
ax.plot(WascoEMDDJFERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoEMDDJFMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoEMDDJFWRF,WascoZComp,label='WRF',color='blue')

# ax.legend(fontsize = 12)
ax.set_xlabel('Winter EMD (m)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoEMDDJF')
# Out:
# (0, 5)

# %%
# Wasco EMD MAM

WascoEMDMAMERA=np.zeros(5)
WascoEMDMAMERA[0]=(wasserstein_distance(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['ERA66.5']))
WascoEMDMAMERA[1]=(wasserstein_distance(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['ERA79']))
WascoEMDMAMERA[2]=(wasserstein_distance(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['ERA106']))
WascoEMDMAMERA[3]=(wasserstein_distance(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['ERA121.5']))
WascoEMDMAMERA[4]=(wasserstein_distance(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['ERA140']))

WascoEMDMAMMERRA=np.zeros(5)
WascoEMDMAMMERRA[0]=(wasserstein_distance(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['MERRA60']))
WascoEMDMAMMERRA[1]=(wasserstein_distance(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['MERRA80']))
WascoEMDMAMMERRA[2]=(wasserstein_distance(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['MERRA100']))
WascoEMDMAMMERRA[3]=(wasserstein_distance(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['MERRA120']))
WascoEMDMAMMERRA[4]=(wasserstein_distance(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['MERRA140']))

WascoEMDMAMWRF=np.zeros(5)
WascoEMDMAMWRF[0]=(wasserstein_distance(WascoWSnanMAM['Lidar60'],WascoWSnanMAM['WRF60']))
WascoEMDMAMWRF[1]=(wasserstein_distance(WascoWSnanMAM['Lidar80'],WascoWSnanMAM['WRF80']))
WascoEMDMAMWRF[2]=(wasserstein_distance(WascoWSnanMAM['Lidar100'],WascoWSnanMAM['WRF100']))
WascoEMDMAMWRF[3]=(wasserstein_distance(WascoWSnanMAM['Lidar120'],WascoWSnanMAM['WRF120']))
WascoEMDMAMWRF[4]=(wasserstein_distance(WascoWSnanMAM['Lidar140'],WascoWSnanMAM['WRF140']))

# %%
# Wasco EMD MAM 

fig,ax=plt.subplots()
ax.plot(WascoEMDMAMERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoEMDMAMMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoEMDMAMWRF,WascoZComp,label='WRF',color='blue')

# ax.legend(fontsize = 12)
ax.set_xlabel('Spring EMD (m)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoEMDMAM')
# Out:
# (0, 5)

# %%
# Wasco EMD JJA

WascoEMDJJAERA=np.zeros(5)
WascoEMDJJAERA[0]=(wasserstein_distance(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['ERA66.5']))
WascoEMDJJAERA[1]=(wasserstein_distance(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['ERA79']))
WascoEMDJJAERA[2]=(wasserstein_distance(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['ERA106']))
WascoEMDJJAERA[3]=(wasserstein_distance(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['ERA121.5']))
WascoEMDJJAERA[4]=(wasserstein_distance(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['ERA140']))

WascoEMDJJAMERRA=np.zeros(5)
WascoEMDJJAMERRA[0]=(wasserstein_distance(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['MERRA60']))
WascoEMDJJAMERRA[1]=(wasserstein_distance(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['MERRA80']))
WascoEMDJJAMERRA[2]=(wasserstein_distance(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['MERRA100']))
WascoEMDJJAMERRA[3]=(wasserstein_distance(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['MERRA120']))
WascoEMDJJAMERRA[4]=(wasserstein_distance(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['MERRA140']))

WascoEMDJJAWRF=np.zeros(5)
WascoEMDJJAWRF[0]=(wasserstein_distance(WascoWSnanJJA['Lidar60'],WascoWSnanJJA['WRF60']))
WascoEMDJJAWRF[1]=(wasserstein_distance(WascoWSnanJJA['Lidar80'],WascoWSnanJJA['WRF80']))
WascoEMDJJAWRF[2]=(wasserstein_distance(WascoWSnanJJA['Lidar100'],WascoWSnanJJA['WRF100']))
WascoEMDJJAWRF[3]=(wasserstein_distance(WascoWSnanJJA['Lidar120'],WascoWSnanJJA['WRF120']))
WascoEMDJJAWRF[4]=(wasserstein_distance(WascoWSnanJJA['Lidar140'],WascoWSnanJJA['WRF140']))

# %%
# Wasco EMD JJA 

fig,ax=plt.subplots()
ax.plot(WascoEMDJJAERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoEMDJJAMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoEMDJJAWRF,WascoZComp,label='WRF',color='blue')

# ax.legend(fontsize = 12)
ax.set_xlabel('Summer EMD (m)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoEMDJJA')
# Out:
# (0, 5)

# %%
# Wasco EMD SON

WascoEMDSONERA=np.zeros(5)
WascoEMDSONERA[0]=(wasserstein_distance(WascoWSnanSON['Lidar60'],WascoWSnanSON['ERA66.5']))
WascoEMDSONERA[1]=(wasserstein_distance(WascoWSnanSON['Lidar80'],WascoWSnanSON['ERA79']))
WascoEMDSONERA[2]=(wasserstein_distance(WascoWSnanSON['Lidar100'],WascoWSnanSON['ERA106']))
WascoEMDSONERA[3]=(wasserstein_distance(WascoWSnanSON['Lidar120'],WascoWSnanSON['ERA121.5']))
WascoEMDSONERA[4]=(wasserstein_distance(WascoWSnanSON['Lidar140'],WascoWSnanSON['ERA140']))

WascoEMDSONMERRA=np.zeros(5)
WascoEMDSONMERRA[0]=(wasserstein_distance(WascoWSnanSON['Lidar60'],WascoWSnanSON['MERRA60']))
WascoEMDSONMERRA[1]=(wasserstein_distance(WascoWSnanSON['Lidar80'],WascoWSnanSON['MERRA80']))
WascoEMDSONMERRA[2]=(wasserstein_distance(WascoWSnanSON['Lidar100'],WascoWSnanSON['MERRA100']))
WascoEMDSONMERRA[3]=(wasserstein_distance(WascoWSnanSON['Lidar120'],WascoWSnanSON['MERRA120']))
WascoEMDSONMERRA[4]=(wasserstein_distance(WascoWSnanSON['Lidar140'],WascoWSnanSON['MERRA140']))

WascoEMDSONWRF=np.zeros(5)
WascoEMDSONWRF[0]=(wasserstein_distance(WascoWSnanSON['Lidar60'],WascoWSnanSON['WRF60']))
WascoEMDSONWRF[1]=(wasserstein_distance(WascoWSnanSON['Lidar80'],WascoWSnanSON['WRF80']))
WascoEMDSONWRF[2]=(wasserstein_distance(WascoWSnanSON['Lidar100'],WascoWSnanSON['WRF100']))
WascoEMDSONWRF[3]=(wasserstein_distance(WascoWSnanSON['Lidar120'],WascoWSnanSON['WRF120']))
WascoEMDSONWRF[4]=(wasserstein_distance(WascoWSnanSON['Lidar140'],WascoWSnanSON['WRF140']))

# %%
# Wasco EMD SON 

fig,ax=plt.subplots()
ax.plot(WascoEMDSONERA,WascoZComp, label = 'ERA-5',color='orange')
ax.plot(WascoEMDSONMERRA,WascoZComp,label='MERRA-2',color='green')
ax.plot(WascoEMDSONWRF,WascoZComp,label='WRF',color='blue')

# ax.legend(fontsize = 12)
ax.set_xlabel('Fall EMD (m)', fontsize = 12)
ax.set_ylabel('Height (m)', fontsize = 12)
ax.set_xlim([0,5])
# plt.savefig('WascoEMDSON')
# Out:
# (0, 5)
